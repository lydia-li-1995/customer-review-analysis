# %%
import pandas as pd
import time
from collections import Counter
from nltk import word_tokenize 
# https://www.nltk.org/_modules/nltk/tokenize.html
# Tokenizers divide strings into lists of substrings.  For example,
# tokenizers can be used to find the words and punctuation in a string
import nltk
import numpy as np
#from wordcloud import WordCloud, STOPWORDS # STOPWORDS
from nltk.corpus import stopwords # stopwords 
import matplotlib.pyplot as plt
import seaborn as sns
import string
import pickle

# %%
def remove_values_from_list(the_list, val):
    return [value for value in the_list if value != val]

def my_preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower() # Step 1: transfer data to lower-case strings
    list_words = word_tokenize(sentence) #Step 2: break the sentences into a list of words
    list_words = remove_values_from_list(list_words, '$') # Step 3: $hashtag$ and $url$ must be filtered
    list_words = remove_values_from_list(list_words, 'hashtag')
    list_words = remove_values_from_list(list_words, 'url')
    # Step 4: filter punctuations
    list_words_return = []
    for s in list_words:
        if s not in string.punctuation:
            list_words_return.append(s)
    # Step 5: some rows might disapear, I give " " to them
    if len(list_words_return) == 0:
        list_words_return.append(" ")
    return (' '.join(list_words_return)) # return a string which words seperated by ' '

def my_preprocess2(sentence):
    sentence = str(sentence)
    sentence = sentence.lower() # Step 1: transfer data to lower-case strings
    list_words = word_tokenize(sentence) #Step 2: break the sentences into a list of words
    list_words = remove_values_from_list(list_words, '$') # Step 3: $hashtag$ and $url$ must be filtered
    list_words = remove_values_from_list(list_words, 'hashtag')
    list_words = remove_values_from_list(list_words, 'url')
    # Step 4: filter punctuations
    list_words_return = []
    for s in list_words:
        if s not in string.punctuation:
            list_words_return.append(s)
    # Step 5: some rows might disapear, I give " " to them
    if len(list_words_return) == 0:
        list_words_return.append(" ")
    return (list_words_return) # return a list of words

# %% [markdown]
# # Section A: read in data and do filtering by punctuations, lower-case transfering, numbers

# %%
# read in train data
start_time = time.time()
path = "/mnt/c/Users/Administrator.DESKTOP-OHBO1TS/Desktop/Prof_Eesley/github/"
df = pd.read_excel(path + "training_set_dec9.xlsx")
print("df.shape",df.shape)
print("===== before fitering =====")
print(df['full_text'][0])
print("this cell takes time:",round(time.time() - start_time,3),"s")
# Out:
# df.shape (10381, 12)
# ===== before fitering =====
# get started with $HASHTAG$ - check out $URL$ and install the client at: $URL$
# this cell takes time: 1.612 s

# %%
# filtering data
start_time = time.time() 
inputDF = df['full_text'].apply(lambda x: my_preprocess(x) )
inputDF = pd.Series(inputDF)
print("I have filtered $hashtag$ and $url$")
print("I have filtered all punctuations, these are:",string.punctuation)
print("===== after fitering =====")
print("each row has datatype= ",type(inputDF[0]))
print(inputDF[0])
print("this cell takes time:",round(time.time() - start_time,3),"s")
# Out:
# I have filtered $hashtag$ and $url$
# I have filtered all punctuations, these are: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# ===== after fitering =====
# each row has datatype=  <class 'str'>
# get started with check out and install the client at
# this cell takes time: 4.257 s

# %%
start_time = time.time()
inputDF_words = df['full_text'].apply(lambda x: my_preprocess2(x) )
print("this cell takes time:",round(time.time() - start_time,3),"s")
# Out:
# this cell takes time: 3.686 s

# %%
len(inputDF_words)
# Out:
# 10381

# %%
# remove punctuation and number/digits
start_time = time.time()

bag_of_words = []
for el in inputDF_words:
    bag_of_words.extend(el)
bag_of_words = list(np.unique(bag_of_words))

print("There are ",len(bag_of_words)," unique words in bag_of_words")
bag_of_words.sort()

starting_words = list(string.ascii_lowercase[:26]) # a-z
ban_words = [str(i) for i in range(0,10)] # 0-9
ban_punctuation = list(string.punctuation)

bag_of_words_new = []
for i in range(len(bag_of_words)):
    #if (i % 100 ==0):
        #print("dealing with word count = ",i)
    words = bag_of_words[i]
    flag1 = True
    flag2 = False
    flag3 = True
    
    for num in ban_words:
        if num in words:
            flag1 = False
            break
    
    for punct in ban_punctuation:
        if punct in words:
            flag3 = False
            break
    
    if words[0] in starting_words:
        flag2 = True
    
    if flag1 and flag2 and flag3:
        bag_of_words_new.append(words)
    else:
        continue
bag_of_words_new = list(np.unique(bag_of_words_new))

print("After filtering, there are ",len(bag_of_words_new)," unique words in bag_of_words")
print("this cell takes time:",round(time.time() - start_time,3),"s")
# Out:
# There are  12225  unique words in bag_of_words
# After filtering, there are  10209  unique words in bag_of_words
# this cell takes time: 0.338 s

# %%
nltk.download('stopwords')
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/zhiyuan8/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-94d2303ac53f> in <module>
#       1 nltk.download('stopwords')
# ----> 2 stopwords = set(stopwords.words('english'))
#
# AttributeError: 'set' object has no attribute 'words'

# %%
bag_of_words_new = [word for word in bag_of_words_new if word not in stopwords] # filter by nltk

bag_of_words_new = list(np.unique(bag_of_words_new))
print("After filtering, there are ",len(bag_of_words_new)," unique words in bag_of_words_new2")
# Out:
# After filtering, there are  10069  unique words in bag_of_words_new2

# %%
# save to file before stemming
f = open(path +  'Zhiyuan_Li_word_dict_before_stemming.csv','w+')
for t in bag_of_words_new:
    f.write(t + '\n')
f.close()
print("finished saving file")
# Out:
# finished saving file

# %% [markdown]
# # Section B: check spelling error
# https://rustyonrampage.github.io/text-mining/2017/11/28/spelling-correction-with-python-and-nltk.html

# %% [markdown]
# #### English words have a max of two repeated characters. Additional characters need to ripped off, otherwise we might add misleading information.

# %%
import re

def reduce_lengthening(text):
    pattern = re.compile(r"(.)\1{2,}")
    return pattern.sub(r"\1\1", text)

# %%
reduce_lengthening( "aaand" )
# Out:
# 'aand'

# %% [markdown]
# #### NLTK has no spell correction module, but there are many other libraries that can perform this task. I’ll using pattern en for this purpose

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(['aand','abandon','abandoned','abandonment','abc','abe','abi','ability','able','aboard',\
                            'abolition','abra','abroad','abruptly','absent','absolute','absolutely','abstract',\
                            'abstracted','abstraction'])

for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))

    # Get a list of `likely` options
    print(spell.candidates(word))
# Out:
# aura
# {'abba', 'bra', 'azra', 'abrc', 'abta', 'sabra', 'cabra', 'agra', 'absa', 'bara', 'aba', 'abram', 'aura', 'abri', 'apra', 'ambra', 'ara'}
# and
# {'wand', 'fand', 'rand', 'hand', 'anand', 'amand', 'sand', 'and', 'land', 'band'}

# %% [markdown]
# ## B-main: run spelling check and build a map between wrong and corrected words

# %%
print("before filtering, number of words:",len(bag_of_words_new))
# Out:
# before filtering, number of words: 10069

# %%
bag_of_words_dict_1 = dict()

# round 1: delete trible duplicating letters 
for word in bag_of_words_new:
    bag_of_words_dict_1[word] = reduce_lengthening(word)
    if word != reduce_lengthening(word):
        print(word," trimmed to be: ",reduce_lengthening(word))
# Out:
# aaand  trimmed to be:  aand
# aliiiiveee  trimmed to be:  aliivee
# baaaaad  trimmed to be:  baad
# dundunduuun  trimmed to be:  dundunduun
# duuun  trimmed to be:  duun
# fiiiiire  trimmed to be:  fiire
# hmmm  trimmed to be:  hmm
# huuuuuge  trimmed to be:  huuge
# ieee  trimmed to be:  iee
# iii  trimmed to be:  ii
# litttle  trimmed to be:  little
# lll  trimmed to be:  ll
# mmmhmm  trimmed to be:  mmhmm
# mooooooooon  trimmed to be:  moon
# pssst  trimmed to be:  psst
# purrrduce  trimmed to be:  purrduce
# shhh  trimmed to be:  shh
# waaay  trimmed to be:  waay

# %%
# round 2: correct the misspelling words
start_time = time.time()
spell = SpellChecker()

misspelled = spell.unknown( list(bag_of_words_dict_1.values()) ) # use trible duplicate deleted words

for word in misspelled:
    # Get the one `most likely` answer
    print(word," is corrected to be: ",spell.correction(word))
# Out:
# grav  is corrected to be:  grave
# firefox  is corrected to be:  firebox
# vinay  is corrected to be:  vinny
# airdropping  is corrected to be:  airdropping
# admins  is corrected to be:  admits
# toothfairy  is corrected to be:  toothfairy
# raincheck  is corrected to be:  raincheck
# seraphid  is corrected to be:  seraphic
# phecda  is corrected to be:  theda
# refactoring  is corrected to be:  factoring
# duh  is corrected to be:  due
# coingate  is corrected to be:  coinage
# carblock  is corrected to be:  warlock
# dvlpmt  is corrected to be:  dvlpmt
# abra  is corrected to be:  aura
# stocklands  is corrected to be:  docklands
# transacts  is corrected to be:  transact
# binance  is corrected to be:  finance
# swissnex  is corrected to be:  swissnex
# validator  is corrected to be:  validators
# changsha  is corrected to be:  changsha
# gettin  is corrected to be:  getting
# hashrate  is corrected to be:  castrate
# walkthough  is corrected to be:  although
# innoxneo  is corrected to be:  innoxneo
# tba  is corrected to be:  tea
# zcash  is corrected to be:  cash
# standford  is corrected to be:  stanford
# unspendable  is corrected to be:  unspeakable
# clich  is corrected to be:  click
# blogging  is corrected to be:  logging
# crypto  is corrected to be:  crypt
# mou  is corrected to be:  you
# etheremerald  is corrected to be:  etheremerald
# shitcoin  is corrected to be:  hitchin
# bauerle  is corrected to be:  bauer
# aand  is corrected to be:  and
# loration  is corrected to be:  location
# pmed  is corrected to be:  pied
# whatisgrav  is corrected to be:  whatisgrav
# sdusd  is corrected to be:  sound
# runthrough  is corrected to be:  run-through
# saini  is corrected to be:  saint
# instaswap  is corrected to be:  instaswap
# barrera  is corrected to be:  carrera
# orisini  is corrected to be:  orsini
# stev  is corrected to be:  step
# alaskans  is corrected to be:  alaskan
# gscp  is corrected to be:  scp
# cryptsy  is corrected to be:  crypts
# resses  is corrected to be:  dresses
# vbft  is corrected to be:  but
# dappradar  is corrected to be:  dappradar
# reevaluate  is corrected to be:  re-evaluate
# viel  is corrected to be:  view
# bitmain  is corrected to be:  britain
# quoinex  is corrected to be:  quine
# eriences  is corrected to be:  sciences
# latam  is corrected to be:  latham
# podcasters  is corrected to be:  podcasters
# coindesk  is corrected to be:  coindesk
# dlive  is corrected to be:  live
# rebrands  is corrected to be:  brands
# ects  is corrected to be:  acts
# gos  is corrected to be:  got
# blocktivity  is corrected to be:  blocktivity
# ogc  is corrected to be:  orc
# ddosing  is corrected to be:  dosing
# ouglas  is corrected to be:  douglas
# mtn  is corrected to be:  man
# fourthstate  is corrected to be:  fourthstate
# ideo  is corrected to be:  idea
# plz  is corrected to be:  plc
# transactive  is corrected to be:  transaction
# hashpower  is corrected to be:  hashpower
# lained  is corrected to be:  gained
# lizardcoin  is corrected to be:  lizardcoin
# mastercoin  is corrected to be:  masterson
# mtgox  is corrected to be:  magnox
# geeky  is corrected to be:  geek
# bitshares  is corrected to be:  bitshares
# etcsummit  is corrected to be:  etcsummit
# ont  is corrected to be:  on
# finnaly  is corrected to be:  final
# mougayar  is corrected to be:  mougayar
# nydfs  is corrected to be:  nodes
# teraexchange  is corrected to be:  teraexchange
# sidechain  is corrected to be:  side-chain
# alephzero  is corrected to be:  alephzero
# stackexchange  is corrected to be:  stackexchange
# http  is corrected to be:  ttp
# immersive  is corrected to be:  immersion
# scamcoins  is corrected to be:  scamcoins
# waay  is corrected to be:  way
# subreddits  is corrected to be:  subreddits
# jeepney  is corrected to be:  stepney
# juna  is corrected to be:  june
# counterarguments  is corrected to be:  counter-arguments
# unfollowed  is corrected to be:  followed
# hashtags  is corrected to be:  hashtags
# hodlers  is corrected to be:  holders
# retweet  is corrected to be:  between
# segwit  is corrected to be:  segni
# analytics  is corrected to be:  analytic
# ccidn  is corrected to be:  acid
# agyei  is corrected to be:  age
# solitidy  is corrected to be:  solitary
# collateralized  is corrected to be:  collateralized
# teemo  is corrected to be:  teems
# arbitrated  is corrected to be:  arbitrate
# jaxx  is corrected to be:  tax
# buntu  is corrected to be:  bantu
# huoxing  is corrected to be:  housing
# fiire  is corrected to be:  fire
# neovm  is corrected to be:  nov.
# scamming  is corrected to be:  slamming
# hackatom  is corrected to be:  hackatom
# thnx  is corrected to be:  thnn
# tweek  is corrected to be:  week
# cardano  is corrected to be:  carno
# lasky  is corrected to be:  lanky
# tuur  is corrected to be:  tour
# flappy  is corrected to be:  floppy
# outro  is corrected to be:  outdo
# chaum  is corrected to be:  charm
# mullvad  is corrected to be:  mulled
# kariz  is corrected to be:  karim
# zaidalkh  is corrected to be:  zaidalkh
# krak  is corrected to be:  kray
# colab  is corrected to be:  cola
# itunes  is corrected to be:  tunes
# lorer  is corrected to be:  lower
# qlink  is corrected to be:  link
# namecheap  is corrected to be:  namecheap
# purevpn  is corrected to be:  previn
# fst  is corrected to be:  st
# kukka  is corrected to be:  pukka
# bft  is corrected to be:  but
# cusden  is corrected to be:  sudden
# evernym  is corrected to be:  every
# mythril  is corrected to be:  mythic
# polkadot  is corrected to be:  polkadot
# noobs  is corrected to be:  boobs
# reimport  is corrected to be:  report
# uber  is corrected to be:  user
# iof  is corrected to be:  of
# canc  is corrected to be:  can
# airdropped  is corrected to be:  airdropped
# globalist  is corrected to be:  loyalist
# coinomi  is corrected to be:  coinomi
# tweeting  is corrected to be:  sweeting
# bitusd  is corrected to be:  bits
# pengtao  is corrected to be:  penta
# ccx  is corrected to be:  cox
# bloq  is corrected to be:  blow
# frontend  is corrected to be:  front-end
# reorg  is corrected to be:  georg
# hoskinson  is corrected to be:  hodkinson
# cryptocurrencies  is corrected to be:  cryptocurrencies
# shukran  is corrected to be:  shukman
# selfie  is corrected to be:  self
# podcast  is corrected to be:  precast
# blacat  is corrected to be:  black
# duun  is corrected to be:  dunn
# placeholder  is corrected to be:  placeholder
# bcash  is corrected to be:  cash
# shicoins  is corrected to be:  shicoins
# sporkin  is corrected to be:  spoken
# koblitz  is corrected to be:  blitz
# liubich  is corrected to be:  limbic
# endeavor  is corrected to be:  endeavour
# wedbush  is corrected to be:  wimbush
# kalaw  is corrected to be:  kala
# shoutout  is corrected to be:  shootout
# nvm  is corrected to be:  nam
# ronn  is corrected to be:  ron
# krykoder  is corrected to be:  krykoder
# diedrich  is corrected to be:  dietrich
# adex  is corrected to be:  alex
# jiachao  is corrected to be:  jiachao
# pastebin  is corrected to be:  wastebin
# alexakis  is corrected to be:  alexis
# depositting  is corrected to be:  depositing
# bitmex  is corrected to be:  bitrex
# trademarked  is corrected to be:  trademark
# delegator  is corrected to be:  delegates
# hitbtc  is corrected to be:  hitbtc
# regathered  is corrected to be:  gathered
# incase  is corrected to be:  in case
# niftywallet  is corrected to be:  niftywallet
# wasm  is corrected to be:  was
# entwickler  is corrected to be:  entwickler
# collab  is corrected to be:  collar
# canceling  is corrected to be:  cancelling
# neocompiler  is corrected to be:  neocompiler
# bitcoinj  is corrected to be:  bitching
# jessi  is corrected to be:  jess
# mixar  is corrected to be:  mixer
# sharded  is corrected to be:  shared
# lightysig  is corrected to be:  lightysig
# bcoin  is corrected to be:  coin
# microblogging  is corrected to be:  microblogging
# digishield  is corrected to be:  digishield
# tmrw  is corrected to be:  trw
# vilen  is corrected to be:  vile
# zamfir  is corrected to be:  zambia
# echidna  is corrected to be:  china
# memopool  is corrected to be:  memopool
# trustory  is corrected to be:  trusty
# hyperdragons  is corrected to be:  hyperdragons
# premine  is corrected to be:  premise
# rika  is corrected to be:  erika
# handcash  is corrected to be:  handcart
# emailed  is corrected to be:  mailed
# devs  is corrected to be:  des
# anding  is corrected to be:  adding
# fyi  is corrected to be:  fbi
# shuvro  is corrected to be:  shur
# hahaha  is corrected to be:  sahara
# hotstuff  is corrected to be:  hotstuff
# unconventionnal  is corrected to be:  unconventional
# junyu  is corrected to be:  june
# guarda  is corrected to be:  guard
# dyverse  is corrected to be:  diverse
# gaians  is corrected to be:  gains
# cafebar  is corrected to be:  caesar
# oancea  is corrected to be:  once
# tfw  is corrected to be:  tow
# parroting  is corrected to be:  parting
# iring  is corrected to be:  bring
# zielin  is corrected to be:  violin
# chadha  is corrected to be:  chad
# evotion  is corrected to be:  emotion
# liqu  is corrected to be:  liu
# hotfix  is corrected to be:  hotfix
# intrade  is corrected to be:  intrude
# anarchapulco  is corrected to be:  anarchapulco
# hiroto  is corrected to be:  hirst
# spcc  is corrected to be:  nspcc
# igital  is corrected to be:  digital
# artmanov  is corrected to be:  romanov
# chainhopping  is corrected to be:  chainhopping
# ands  is corrected to be:  and
# clowder  is corrected to be:  clower
# artamonov  is corrected to be:  artamonov
# botnets  is corrected to be:  bonnets
# ravencoin  is corrected to be:  ravencoin
# eriments  is corrected to be:  elements
# emeraldsdk  is corrected to be:  emeralds
# tweets  is corrected to be:  sweets
# udon  is corrected to be:  upon
# anthonys  is corrected to be:  anthony
# ppelmann  is corrected to be:  eppelmann
# jeemaa  is corrected to be:  leeman
# bitcorati  is corrected to be:  bitcorati
# wetware  is corrected to be:  netware
# maximalists  is corrected to be:  maximalists
# zooz  is corrected to be:  zoo
# auditable  is corrected to be:  suitable
# gude  is corrected to be:  guide
# neoray  is corrected to be:  nearly
# plugin  is corrected to be:  plug-in
# ensan  is corrected to be:  ensa
# gpl  is corrected to be:  gp
# mitigations  is corrected to be:  mitigation
# phishing  is corrected to be:  fishing
# zac  is corrected to be:  mac
# erience  is corrected to be:  evidence
# hyperledger  is corrected to be:  hyperledger
# dyassab  is corrected to be:  assab
# buildboard  is corrected to be:  billboard
# agrello  is corrected to be:  aurelio
# ocap  is corrected to be:  cap
# guilherme  is corrected to be:  guillermo
# smartphones  is corrected to be:  smartphones
# bollywood  is corrected to be:  hollywood
# internship  is corrected to be:  internship
# anded  is corrected to be:  added
# wiki  is corrected to be:  niki
# zksnark  is corrected to be:  zksnark
# deepsea  is corrected to be:  deep-sea
# ethermint  is corrected to be:  ethermint
# csw  is corrected to be:  cow
# ecf  is corrected to be:  ec
# etctoday  is corrected to be:  etctoday
# wendel  is corrected to be:  mendel
# bugfixes  is corrected to be:  suffixes
# provably  is corrected to be:  probably
# yez  is corrected to be:  yes
# blolys  is corrected to be:  boys
# jkz  is corrected to be:  jez
# bcrash  is corrected to be:  crash
# gaslighting  is corrected to be:  alighting
# lores  is corrected to be:  lords
# ohioans  is corrected to be:  onions
# lendit  is corrected to be:  lending
# dmed  is corrected to be:  died
# forefronts  is corrected to be:  forefront
# msagnask  is corrected to be:  msagnask
# bitcoindecentral  is corrected to be:  bitcoindecentral
# kmplayer  is corrected to be:  player
# neosmartecon  is corrected to be:  neosmartecon
# quickpay  is corrected to be:  quickly
# drivechains  is corrected to be:  drivechains
# etf  is corrected to be:  etc
# reposted  is corrected to be:  reported
# moneybeat  is corrected to be:  moneybeat
# enthusiatic  is corrected to be:  enthusiastic
# cryptokitties  is corrected to be:  cryptokitties
# dvlp  is corrected to be:  dlp
# peacebridge  is corrected to be:  piercebridge
# ectations  is corrected to be:  stations
# analyzes  is corrected to be:  analyses
# tusd  is corrected to be:  turd
# bling  is corrected to be:  being
# startups  is corrected to be:  start-ups
# cryptoworld  is corrected to be:  cryptoworld
# jpmorgan  is corrected to be:  morgan
# floof  is corrected to be:  floor
# tabconf  is corrected to be:  tabconf
# fss  is corrected to be:  fuss
# demeester  is corrected to be:  dempster
# delegators  is corrected to be:  delegates
# gaslimit  is corrected to be:  gaslight
# bratuskins  is corrected to be:  bratuskins
# alabamians  is corrected to be:  albanians
# janislav  is corrected to be:  ladislav
# blockpress  is corrected to be:  blockpress
# rebond  is corrected to be:  rebound
# venmo  is corrected to be:  venom
# enses  is corrected to be:  senses
# offchain  is corrected to be:  offchain
# whitepaper  is corrected to be:  wastepaper
# adtech  is corrected to be:  attach
# yuefeng  is corrected to be:  yuefeng
# shoutouts  is corrected to be:  shortcuts
# fazel  is corrected to be:  hazel
# lookin  is corrected to be:  looking
# barinov  is corrected to be:  marino
# bitvo  is corrected to be:  bit
# hominem  is corrected to be:  homines
# kademlia  is corrected to be:  karelia
# cnbc  is corrected to be:  nbc
# tgt  is corrected to be:  tt
# crowdsourced  is corrected to be:  crowdsourced
# degov  is corrected to be:  devon
# hybercubes  is corrected to be:  hybercubes
# hodling  is corrected to be:  holding
# trustlessly  is corrected to be:  restlessly
# satoshi  is corrected to be:  satish
# verifiably  is corrected to be:  verifiable
# morgenpeck  is corrected to be:  morgenpeck
# stablecoin  is corrected to be:  stablecoin
# website  is corrected to be:  webster
# kimi  is corrected to be:  kim
# slazas  is corrected to be:  plazas
# blockstack  is corrected to be:  blockstack
# nipopow  is corrected to be:  nippon
# bashco  is corrected to be:  basic
# tourianski  is corrected to be:  tourianski
# punica  is corrected to be:  punic
# strato  is corrected to be:  strata
# alisons  is corrected to be:  alison
# taaki  is corrected to be:  taki
# aggregator  is corrected to be:  aggregate
# localstorage  is corrected to be:  localstorage
# syncing  is corrected to be:  singing
# nipopows  is corrected to be:  nipopows
# monetizing  is corrected to be:  monetizing
# blocksizes  is corrected to be:  blocksizes
# underserved  is corrected to be:  undeserved
# tix  is corrected to be:  six
# tokenisation  is corrected to be:  tokenisation
# slackbot  is corrected to be:  slackbot
# mro  is corrected to be:  mr
# strawman  is corrected to be:  strachan
# jeremie  is corrected to be:  jeremy
# crytochicks  is corrected to be:  crytochicks
# dogefather  is corrected to be:  dogefather
# canesin  is corrected to be:  canes
# rebalancing  is corrected to be:  balancing
# micropayments  is corrected to be:  micropayments
# cyphernerds  is corrected to be:  cyphernerds
# cashaddr  is corrected to be:  cashaddr
# shibismas  is corrected to be:  shibismas
# webassembly  is corrected to be:  reassembly
# groundbreaking  is corrected to be:  ground-breaking
# youtube  is corrected to be:  couture
# delivey  is corrected to be:  delivery
# subreddit  is corrected to be:  subreddit
# vantablack  is corrected to be:  vantablack
# signup  is corrected to be:  sign
# baimaohui  is corrected to be:  baimaohui
# llvm  is corrected to be:  love
# bitflyer  is corrected to be:  bitflyer
# pawe  is corrected to be:  page
# bitoasis  is corrected to be:  mitosis
# ajoutes  is corrected to be:  routes
# sockpuppets  is corrected to be:  sockpuppets
# ected  is corrected to be:  acted
# oculus  is corrected to be:  modulus
# smartx  is corrected to be:  smart
# legalchain  is corrected to be:  legalchain
# seminole  is corrected to be:  seminal
# cryptos  is corrected to be:  crypts
# bzx  is corrected to be:  box
# siloed  is corrected to be:  silted
# ewasm  is corrected to be:  was
# ockam  is corrected to be:  occam
# vlog  is corrected to be:  log
# chainday  is corrected to be:  chainsaw
# coinfundr  is corrected to be:  coinfundr
# spoofing  is corrected to be:  spooning
# cosmwasm  is corrected to be:  cosmas
# squirreling  is corrected to be:  squirreling
# hmacs  is corrected to be:  macs
# cryptorank  is corrected to be:  cryptorank
# bitfury  is corrected to be:  bibury
# vandalize  is corrected to be:  vandalized
# paypal  is corrected to be:  papal
# kartheiser  is corrected to be:  kartheiser
# coinhako  is corrected to be:  coinhako
# agharta  is corrected to be:  aghast
# pushback  is corrected to be:  pushback
# basezero  is corrected to be:  basezero
# wassim  is corrected to be:  wasim
# dogedex  is corrected to be:  dogedex
# donut  is corrected to be:  dont
# propy  is corrected to be:  prop
# inturpreter  is corrected to be:  interpreter
# devcon  is corrected to be:  devon
# usdx  is corrected to be:  us
# utrust  is corrected to be:  trust
# asos  is corrected to be:  asks
# husian  is corrected to be:  human
# bitcoine  is corrected to be:  bitching
# mainet  is corrected to be:  magnet
# swft  is corrected to be:  soft
# vertbase  is corrected to be:  verbose
# fadada  is corrected to be:  canada
# iohk  is corrected to be:  work
# owallet  is corrected to be:  wallet
# dgamemaker  is corrected to be:  framemaker
# inu  is corrected to be:  in
# erts  is corrected to be:  arts
# arkansians  is corrected to be:  arkansas
# liana  is corrected to be:  diana
# blockasset  is corrected to be:  blockasset
# elastos  is corrected to be:  elastic
# plugins  is corrected to be:  plains
# redecentralize  is corrected to be:  decentralize
# gamed  is corrected to be:  game
# scrypt  is corrected to be:  script
# monkeycoin  is corrected to be:  monkeycoin
# motorspeedway  is corrected to be:  motorspeedway
# karapetsas  is corrected to be:  karapetsas
# akomba  is corrected to be:  aroma
# truebit  is corrected to be:  truest
# qq  is corrected to be:  q
# disscusion  is corrected to be:  discussion
# gmo  is corrected to be:  go
# decentral  is corrected to be:  central
# blogs  is corrected to be:  blows
# gamers  is corrected to be:  games
# danke  is corrected to be:  dance
# linzhi  is corrected to be:  lizhi
# nchain  is corrected to be:  chain
# whalepanda  is corrected to be:  whalepanda
# cyn  is corrected to be:  can
# kaipai  is corrected to be:  taipei
# inline  is corrected to be:  online
# debugged  is corrected to be:  debugger
# bitcoins  is corrected to be:  bitching
# racegod  is corrected to be:  raced
# finestone  is corrected to be:  firestone
# hongfei  is corrected to be:  hongfei
# mbl  is corrected to be:  ml
# cosmosjs  is corrected to be:  cosmos
# ecies  is corrected to be:  eyes
# skype  is corrected to be:  skye
# sidechains  is corrected to be:  side-chain
# stratis  is corrected to be:  straits
# skeptics  is corrected to be:  sceptics
# exch  is corrected to be:  each
# altenative  is corrected to be:  alternative
# sagenet  is corrected to be:  agent
# blocklist  is corrected to be:  blacklist
# defisurance  is corrected to be:  defisurance
# demoed  is corrected to be:  demoted
# ansion  is corrected to be:  mansion
# rebonding  is corrected to be:  rebounding
# coinmarketcap  is corrected to be:  coinmarketcap
# magraw  is corrected to be:  mcgraw
# abt  is corrected to be:  at
# librabft  is corrected to be:  librabft
# spams  is corrected to be:  seams
# grantees  is corrected to be:  grandees
# dvlpers  is corrected to be:  helpers
# spokkz  is corrected to be:  spoke
# redelegation  is corrected to be:  delegation
# cfca  is corrected to be:  cfcs
# aunctioned  is corrected to be:  functioned
# convo  is corrected to be:  convoy
# dwork  is corrected to be:  work
# tlv  is corrected to be:  tv
# thinsdk  is corrected to be:  think
# fosun  is corrected to be:  bosun
# gentx  is corrected to be:  gents
# unbonded  is corrected to be:  unbounded
# vegarelay  is corrected to be:  vegarelay
# coingeek  is corrected to be:  coingeek
# philcoa  is corrected to be:  philo
# devadoss  is corrected to be:  devadoss
# keccak  is corrected to be:  mecca
# cryptospace  is corrected to be:  cryptospace
# coinex  is corrected to be:  coined
# sechet  is corrected to be:  secret
# cryptocurrecy  is corrected to be:  cryptocurrecy
# ecting  is corrected to be:  acting
# ecips  is corrected to be:  lips
# dundunduun  is corrected to be:  dundunduun
# escrowed  is corrected to be:  screwed
# osaru  is corrected to be:  saru
# benzinga  is corrected to be:  bending
# onboarding  is corrected to be:  boarding
# recommitted  is corrected to be:  committed
# modl  is corrected to be:  model
# upvote  is corrected to be:  vote
# linting  is corrected to be:  lifting
# govtx  is corrected to be:  govt
# spv  is corrected to be:  spr
# privateinternetaccess  is corrected to be:  privateinternetaccess
# webpack  is corrected to be:  webpack
# undelegating  is corrected to be:  delegating
# tipbot  is corrected to be:  talbot
# bogatyrev  is corrected to be:  bogatyrev
# finners  is corrected to be:  fingers
# modularized  is corrected to be:  modularised
# hirayama  is corrected to be:  hirayama
# pleather  is corrected to be:  leather
# programed  is corrected to be:  programmed
# edia  is corrected to be:  media
# slowmist  is corrected to be:  slowest
# sporklin  is corrected to be:  sparkling
# metahash  is corrected to be:  metaphase
# glendon  is corrected to be:  grendon
# fermion  is corrected to be:  version
# fcas  is corrected to be:  acas
# troubleshoot  is corrected to be:  troubleshooter
# orderbooks  is corrected to be:  orderbooks
# moneygram  is corrected to be:  monogram
# zeepin  is corrected to be:  keeping
# webbers  is corrected to be:  webber
# monikers  is corrected to be:  moniker
# lanxess  is corrected to be:  lanes
# shitcoins  is corrected to be:  shitcoins
# bitlicense  is corrected to be:  bitlicense
# sesameseed  is corrected to be:  sesameseed
# aua  is corrected to be:  aha
# cospos  is corrected to be:  cosmos
# stargazer  is corrected to be:  stargazer
# finalizes  is corrected to be:  finalized
# cdn  is corrected to be:  can
# ambients  is corrected to be:  ambient
# joi  is corrected to be:  job
# europas  is corrected to be:  europa
# demystifies  is corrected to be:  demystified
# assc  is corrected to be:  ass
# iniz  is corrected to be:  diniz
# bitcoinabc  is corrected to be:  bitcoinabc
# onchain  is corrected to be:  chain
# antminer  is corrected to be:  antoine
# bolychevsky  is corrected to be:  bolychevsky
# olieman  is corrected to be:  policeman
# timezone  is corrected to be:  time-zone
# hmu  is corrected to be:  hm
# practicle  is corrected to be:  practice
# neogas  is corrected to be:  vegas
# lotionjs  is corrected to be:  lotions
# precompiled  is corrected to be:  recompiled
# tokenizing  is corrected to be:  tokenizing
# bitbeat  is corrected to be:  ritblat
# sochi  is corrected to be:  such
# townsville  is corrected to be:  brownsville
# whitener  is corrected to be:  whitened
# genkicell  is corrected to be:  genkicell
# nakamoto  is corrected to be:  sakamoto
# cheapair  is corrected to be:  cheaper
# nonfunctional  is corrected to be:  non-functional
# shg  is corrected to be:  she
# proj  is corrected to be:  pro
# eventbrite  is corrected to be:  eventbrite
# nimo  is corrected to be:  niro
# vaibhav  is corrected to be:  vaibhav
# zeux  is corrected to be:  zeus
# envision  is corrected to be:  division
# londdon  is corrected to be:  london
# gowithmi  is corrected to be:  gowithmi
# hackaton  is corrected to be:  hickton
# uasf  is corrected to be:  usaf
# eips  is corrected to be:  lips
# reportingstate  is corrected to be:  reportingstate
# vpns  is corrected to be:  vans
# zamphir  is corrected to be:  camphor
# boilerplate  is corrected to be:  boilerplate
# kuhlman  is corrected to be:  kuhlmann
# cryptographic  is corrected to be:  cryptographer
# thiel  is corrected to be:  thief
# pittleman  is corrected to be:  pittman
# synced  is corrected to be:  since
# javascript  is corrected to be:  javascript
# nvidia  is corrected to be:  india
# dogeversary  is corrected to be:  dogeversary
# neofish  is corrected to be:  selfish
# puv  is corrected to be:  put
# fungibility  is corrected to be:  tangibility
# nfts  is corrected to be:  nuts
# wanxiang  is corrected to be:  wanting
# guiyang  is corrected to be:  guiding
# embeddable  is corrected to be:  embeddable
# reddit  is corrected to be:  geddit
# btrash  is corrected to be:  trash
# behance  is corrected to be:  chance
# zk  is corrected to be:  uk
# codewalk  is corrected to be:  sidewalk
# webpage  is corrected to be:  seepage
# ensive  is corrected to be:  pensive
# buitink  is corrected to be:  biting
# bullishness  is corrected to be:  bullishness
# dicarlo  is corrected to be:  carlo
# decrypt  is corrected to be:  crypt
# livestream  is corrected to be:  sidestream
# biggies  is corrected to be:  biggins
# frogger  is corrected to be:  roger
# karpeles  is corrected to be:  marples
# liftoff  is corrected to be:  lift-off
# jonald  is corrected to be:  donald
# arqit  is corrected to be:  art
# hodl  is corrected to be:  hold
# khoury  is corrected to be:  hours
# pirestani  is corrected to be:  pirestani
# icymi  is corrected to be:  ici
# helpdesk  is corrected to be:  helpless
# maintainer  is corrected to be:  maintained
# dist  is corrected to be:  list
# bitvote  is corrected to be:  bitte
# minsauce  is corrected to be:  minsauce
# dogeillionaire  is corrected to be:  dogeillionaire
# newsbtc  is corrected to be:  newsboy
# schnorr  is corrected to be:  schnur
# weifund  is corrected to be:  refund
# maian  is corrected to be:  main
# favorites  is corrected to be:  favourites
# tsankov  is corrected to be:  tanko
# coursera  is corrected to be:  course
# mintchalk  is corrected to be:  mintchalk
# cryptocribs  is corrected to be:  cryptocribs
# lixar  is corrected to be:  liar
# cloudflare  is corrected to be:  cloudflare
# bitregistro  is corrected to be:  bitregistro
# leverington  is corrected to be:  everington
# annouce  is corrected to be:  announce
# eid  is corrected to be:  did
# hexlant  is corrected to be:  extant
# jentzsch  is corrected to be:  jentzsch
# qryptos  is corrected to be:  crypts
# krw  is corrected to be:  kew
# retweeted  is corrected to be:  retreated
# protocolo  is corrected to be:  protocol
# colourise  is corrected to be:  colourist
# simplepolicy  is corrected to be:  simplepolicy
# certik  is corrected to be:  certain
# scanta  is corrected to be:  santa
# aggregators  is corrected to be:  aggregates
# maximalism  is corrected to be:  minimalism
# cryptoschwartz  is corrected to be:  cryptoschwartz
# google  is corrected to be:  goole
# chainalysis  is corrected to be:  chainalysis
# chainid  is corrected to be:  chained
# loitability  is corrected to be:  liability
# bitwires  is corrected to be:  bitwires
# algo  is corrected to be:  also
# erimental  is corrected to be:  oriental
# upvotes  is corrected to be:  votes
# blockheight  is corrected to be:  blockheight
# localchest  is corrected to be:  localchest
# shoucheng  is corrected to be:  slouching
# beijingers  is corrected to be:  beijingers
# functionalities  is corrected to be:  functionalities
# drumroll  is corrected to be:  drumroll
# bitek  is corrected to be:  bite
# tokenization  is corrected to be:  tokenization
# socal  is corrected to be:  local
# blocksplains  is corrected to be:  blocksplains
# paronyan  is corrected to be:  parsonian
# dogecoinsocksforthehomeless  is corrected to be:  dogecoinsocksforthehomeless
# regen  is corrected to be:  regent
# spuul  is corrected to be:  paul
# thankies  is corrected to be:  hankies
# ethereumjs  is corrected to be:  ethereumjs
# bitpanda  is corrected to be:  bitpanda
# shibe  is corrected to be:  shine
# poon  is corrected to be:  soon
# nnc  is corrected to be:  inc
# rmit  is corrected to be:  remit
# unbanked  is corrected to be:  unbanned
# identitymind  is corrected to be:  identitymind
# xlang  is corrected to be:  lang
# bitcointravel  is corrected to be:  bitcointravel
# favs  is corrected to be:  fans
# eriencing  is corrected to be:  orienting
# standout  is corrected to be:  handout
# ress  is corrected to be:  less
# websites  is corrected to be:  webster
# incentivize  is corrected to be:  incentive
# backpage  is corrected to be:  package
# artanomov  is corrected to be:  artanomov
# txid  is corrected to be:  this
# dapps  is corrected to be:  apps
# dragonchain  is corrected to be:  dragonchain
# algos  is corrected to be:  argos
# gitcoin  is corrected to be:  hitchin
# novogratz  is corrected to be:  novogratz
# alkaid  is corrected to be:  laid
# loits  is corrected to be:  lots
# osx  is corrected to be:  osf
# ruleset  is corrected to be:  rules
# bitbox  is corrected to be:  bimbo
# yikes  is corrected to be:  likes
# airbitz  is corrected to be:  tirpitz
# namecalling  is corrected to be:  name-calling
# etcv  is corrected to be:  etc
# btt  is corrected to be:  but
# vaporware  is corrected to be:  vaporware
# ethereumclassiclabs  is corrected to be:  ethereumclassiclabs
# rbf  is corrected to be:  ref
# legalese  is corrected to be:  legalise
# edcon  is corrected to be:  escon
# smaug  is corrected to be:  smug
# naoto  is corrected to be:  nato
# scammers  is corrected to be:  slammers
# thekey  is corrected to be:  they
# iost  is corrected to be:  most
# joystream  is corrected to be:  jetstream
# dapp  is corrected to be:  damp
# adrealm  is corrected to be:  dream
# ecoboost  is corrected to be:  ecoboost
# xrp  is corrected to be:  crp
# merkle  is corrected to be:  meikle
# testnets  is corrected to be:  tenets
# devgrant  is corrected to be:  deviant
# natu  is corrected to be:  nato
# redpulse  is corrected to be:  repulse
# gocoin  is corrected to be:  coin
# trx  is corrected to be:  try
# stablecoins  is corrected to be:  stablecoins
# rendong  is corrected to be:  rending
# cybersecurity  is corrected to be:  cybersecurity
# ieo  is corrected to be:  ie
# rumor  is corrected to be:  rumour
# sfox  is corrected to be:  fox
# aeron  is corrected to be:  apron
# panelists  is corrected to be:  panellists
# hqckaton  is corrected to be:  hickton
# xapo  is corrected to be:  apo
# blogpost  is corrected to be:  blogpost
# gifting  is corrected to be:  lifting
# bpos  is corrected to be:  bros
# websummit  is corrected to be:  websummit
# tweetdraw  is corrected to be:  tweetdraw
# dakotans  is corrected to be:  dakotas
# blucon  is corrected to be:  blacon
# kehanetleriniz  is corrected to be:  kehanetleriniz
# html  is corrected to be:  tml
# devoxx  is corrected to be:  devon
# transcation  is corrected to be:  transaction
# flowee  is corrected to be:  flower
# dctrl  is corrected to be:  ctrl
# nential  is corrected to be:  central
# roadmaps  is corrected to be:  roadmap
# subcommands  is corrected to be:  subcommands
# shills  is corrected to be:  skills
# sovrin  is corrected to be:  soaring
# ryu  is corrected to be:  rye
# bertoni  is corrected to be:  berton
# incentivizing  is corrected to be:  incentivizing
# merkling  is corrected to be:  marking
# ecit  is corrected to be:  exit
# jer  is corrected to be:  her
# neteller  is corrected to be:  teller
# hcmc  is corrected to be:  cmc
# neoecoboost  is corrected to be:  neoecoboost
# blocksize  is corrected to be:  blocksize
# cryptogeek  is corrected to be:  cryptogeek
# huayi  is corrected to be:  hay
# dogethereum  is corrected to be:  dogethereum
# superhard  is corrected to be:  supercar
# tomaz  is corrected to be:  topaz
# interchain  is corrected to be:  interchain
# timeline  is corrected to be:  tideline
# prioritizes  is corrected to be:  priorities
# vunk  is corrected to be:  sunk
# dropdown  is corrected to be:  drop-down
# downloader  is corrected to be:  downloaded
# afri  is corrected to be:  fri
# ayahuasca  is corrected to be:  ayahuasca
# linkedin  is corrected to be:  linked
# changelly  is corrected to be:  chantilly
# comission  is corrected to be:  commission
# cryptlets  is corrected to be:  cryptlets
# linux  is corrected to be:  linx
# dumbfounding  is corrected to be:  dumbfounding
# gallippi  is corrected to be:  gallipoli
# walkthrough  is corrected to be:  walkthrough
# kimis  is corrected to be:  kiwis
# poyo  is corrected to be:  polo
# honored  is corrected to be:  honoured
# licette  is corrected to be:  licence
# opcodes  is corrected to be:  codes
# xcs  is corrected to be:  cs
# uncensorable  is corrected to be:  uncensorable
# sidechained  is corrected to be:  sidechained
# bucash  is corrected to be:  cash
# spendbch  is corrected to be:  spendbch
# arvicco  is corrected to be:  arvicco
# bugfix  is corrected to be:  suffix
# medias  is corrected to be:  media
# cryptoeconomic  is corrected to be:  cryptoeconomic
# nblocks  is corrected to be:  blocks
# cryptoeconomics  is corrected to be:  cryptoeconomics
# dogemas  is corrected to be:  dogmas
# decenter  is corrected to be:  decanter
# encrypt  is corrected to be:  crypt
# zc  is corrected to be:  c
# dropbox  is corrected to be:  dropbox
# harbourfront  is corrected to be:  harbourfront
# granddoge  is corrected to be:  grandiose
# zsolt  is corrected to be:  sort
# bithumb  is corrected to be:  thumb
# ontknight  is corrected to be:  one-night
# mythbusters  is corrected to be:  mythbusters
# pwc  is corrected to be:  pc
# bitcoincash  is corrected to be:  bitcoincash
# infinito  is corrected to be:  infinite
# reuploaded  is corrected to be:  reloaded
# wtf  is corrected to be:  wwf
# neoid  is corrected to be:  need
# afterparty  is corrected to be:  afterparty
# unitimes  is corrected to be:  unities
# jiaotong  is corrected to be:  liaodong
# llm  is corrected to be:  elm
# ddxf  is corrected to be:  dxf
# langsec  is corrected to be:  langley
# maximalist  is corrected to be:  minimalist
# kthxbye  is corrected to be:  kthxbye
# goerli  is corrected to be:  georgi
# nowa  is corrected to be:  now
# repost  is corrected to be:  report
# dex  is corrected to be:  de
# downloads  is corrected to be:  download
# netwrk  is corrected to be:  network
# kappler  is corrected to be:  apple
# webhallen  is corrected to be:  webhallen
# reactjs  is corrected to be:  reacts
# olabilir  is corrected to be:  olabilir
# oyente  is corrected to be:  odette
# solium  is corrected to be:  sodium
# hangout  is corrected to be:  handout
# bakon  is corrected to be:  bacon
# sundog  is corrected to be:  sunday
# yunbi  is corrected to be:  fungi
# attwater  is corrected to be:  atwater
# neoland  is corrected to be:  newland
# reupload  is corrected to be:  reload
# jk  is corrected to be:  uk
# bolchevshy  is corrected to be:  bolchevshy
# bontje  is corrected to be:  bottle
# chainhops  is corrected to be:  chainhops
# sparkpool  is corrected to be:  sparkpool
# github  is corrected to be:  citub
# interns  is corrected to be:  intern
# uploaded  is corrected to be:  unloaded
# yonsei  is corrected to be:  onset
# rizun  is corrected to be:  run
# lohja  is corrected to be:  lorna
# eur  is corrected to be:  our
# hexa  is corrected to be:  hela
# rebating  is corrected to be:  relating
# apac  is corrected to be:  pac
# cgas  is corrected to be:  gas
# lains  is corrected to be:  gains
# demoing  is corrected to be:  demoting
# hashcash  is corrected to be:  hashish
# hackethon  is corrected to be:  hackethon
# hashed  is corrected to be:  washed
# coingame  is corrected to be:  coinage
# kuppe  is corrected to be:  tuppe
# coincheck  is corrected to be:  coincheck
# muzika  is corrected to be:  monika
# versionbits  is corrected to be:  versionbits
# karpischek  is corrected to be:  karpischek
# wilcke  is corrected to be:  wicke
# moni  is corrected to be:  mini
# ipo  is corrected to be:  po
# optech  is corrected to be:  speech
# czaban  is corrected to be:  cabin
# hidskes  is corrected to be:  hides
# monetization  is corrected to be:  monetisation
# tippr  is corrected to be:  tipper
# merch  is corrected to be:  march
# danielassab  is corrected to be:  danielassab
# chrisr  is corrected to be:  christ
# userbase  is corrected to be:  username
# kucoin  is corrected to be:  coin
# nascar  is corrected to be:  lascar
# kyc  is corrected to be:  myc
# felfoldi  is corrected to be:  felfoldi
# antshare  is corrected to be:  antshare
# torrenting  is corrected to be:  tormenting
# kindles  is corrected to be:  kindled
# distro  is corrected to be:  bistro
# rollovers  is corrected to be:  rollover
# wozniak  is corrected to be:  wozniak
# ulbricht  is corrected to be:  albrecht
# futarchy  is corrected to be:  autarchy
# etclabs  is corrected to be:  netlabs
# misc  is corrected to be:  miss
# utc  is corrected to be:  etc
# az  is corrected to be:  a
# lmax  is corrected to be:  max
# peacerelay  is corrected to be:  peacerelay
# treap  is corrected to be:  treat
# disassembler  is corrected to be:  disassembled
# stoever  is corrected to be:  steve
# ananya  is corrected to be:  anaya
# keiser  is corrected to be:  kaiser
# sharding  is corrected to be:  sharing
# erimented  is corrected to be:  oriented
# ccid  is corrected to be:  acid
# verticle  is corrected to be:  article
# gumi  is corrected to be:  gum
# neoworkshop  is corrected to be:  neoworkshop
# babalola  is corrected to be:  babalola
# getmarkets  is corrected to be:  getmarkets
# sendtx  is corrected to be:  sent
# cew  is corrected to be:  new
# schellingcoin  is corrected to be:  schellingcoin
# jentzsh  is corrected to be:  kentish
# livestreaming  is corrected to be:  livestreaming
# tshirt  is corrected to be:  shirt
# jeju  is corrected to be:  jesu
# moar  is corrected to be:  moor
# larimer  is corrected to be:  latimer
# upvoting  is corrected to be:  voting
# coino  is corrected to be:  coins
# whatsapp  is corrected to be:  whatsapp
# noninterventionism  is corrected to be:  non-interventionist
# favored  is corrected to be:  favoured
# hypersnakes  is corrected to be:  hypersnakes
# permissioned  is corrected to be:  permission
# callbacks  is corrected to be:  tailbacks
# nameservice  is corrected to be:  nameservice
# cryptocandy  is corrected to be:  cryptocandy
# anylog  is corrected to be:  analog
# kanazawa  is corrected to be:  kanawa
# starkillers  is corrected to be:  starkillers
# chubble  is corrected to be:  hubble
# andr  is corrected to be:  and
# chainbet  is corrected to be:  chained
# pyethapps  is corrected to be:  pyethapps
# rochi  is corrected to be:  roche
# lilypad  is corrected to be:  lilya
# yesno  is corrected to be:  yes/no
# incentivization  is corrected to be:  incentivization
# peterlinx  is corrected to be:  petering
# infographics  is corrected to be:  infographics
# digitalize  is corrected to be:  digitalis
# localbitcoin  is corrected to be:  localbitcoin
# tos  is corrected to be:  to
# trezor  is corrected to be:  trevor
# labeling  is corrected to be:  labelling
# recieve  is corrected to be:  receive
# cryptokitten  is corrected to be:  cryptokitten
# alsindi  is corrected to be:  albini
# showerthought  is corrected to be:  showerthought
# cosyst  is corrected to be:  cost
# kvstore  is corrected to be:  store
# tual  is corrected to be:  dual
# mngo  is corrected to be:  mungo
# rinkeby  is corrected to be:  rickety
# swisscom  is corrected to be:  swisscom
# zec  is corrected to be:  ec
# decentrazlied  is corrected to be:  decentralised
# shapeshift  is corrected to be:  shakeshaft
# despeignes  is corrected to be:  despeignes
# fintech  is corrected to be:  finch
# lored  is corrected to be:  lord
# cryptokitty  is corrected to be:  cryptokitty
# edilson  is corrected to be:  edison
# factoids  is corrected to be:  factors
# bobesled  is corrected to be:  bobbled
# bittorrent  is corrected to be:  bittorrent
# buildn  is corrected to be:  build
# idex  is corrected to be:  idea
# arkadiy  is corrected to be:  arkady
# minglechain  is corrected to be:  minglechain
# memobch  is corrected to be:  meloch
# linter  is corrected to be:  winter
# sbi  is corrected to be:  sri
# ngd  is corrected to be:  nod
# heisenbug  is corrected to be:  heisenberg
# inslee  is corrected to be:  inside
# lanza  is corrected to be:  lanka
# ducth  is corrected to be:  dutch
# qrc  is corrected to be:  arc
# summerwill  is corrected to be:  summerhill
# nyc  is corrected to be:  nec
# bridgette  is corrected to be:  bridget
# crowdfunded  is corrected to be:  crowdfunded
# redelegating  is corrected to be:  delegating
# fivethirtyeight  is corrected to be:  fivethirtyeight
# lodder  is corrected to be:  ladder
# lanations  is corrected to be:  nations
# zhoudong  is corrected to be:  zhoudong
# matpool  is corrected to be:  matpool
# jotta  is corrected to be:  lotta
# mempools  is corrected to be:  mempools
# slideshare  is corrected to be:  slideshare
# vbp  is corrected to be:  bp
# wordcloud  is corrected to be:  wordcloud
# identicons  is corrected to be:  identicons
# alts  is corrected to be:  arts
# winklevoss  is corrected to be:  winklevoss
# etn  is corrected to be:  ten
# debuting  is corrected to be:  debating
# aws  is corrected to be:  was
# aphelion  is corrected to be:  adhesion
# nighter  is corrected to be:  lighter
# hashes  is corrected to be:  ashes
# unbonding  is corrected to be:  unbending
# xmr  is corrected to be:  mr
# statechains  is corrected to be:  statechains
# kickstarting  is corrected to be:  kickstarting
# amigos  is corrected to be:  amigo
# orbita  is corrected to be:  orbit
# inflekt  is corrected to be:  inflict
# democratizing  is corrected to be:  democratising
# etcland  is corrected to be:  england
# hzf  is corrected to be:  hz
# skrill  is corrected to be:  skill
# huawei  is corrected to be:  hawes
# bitcoiners  is corrected to be:  bitchiness
# crug  is corrected to be:  drug
# kwon  is corrected to be:  won
# ict  is corrected to be:  it
# collaterize  is corrected to be:  collaterize
# hackathon  is corrected to be:  hackathon
# cebe  is corrected to be:  cube
# stossel  is corrected to be:  tossed
# tmw  is corrected to be:  bmw
# enapi  is corrected to be:  nazi
# halfwits  is corrected to be:  halfwit
# ovejas  is corrected to be:  overs
# brigading  is corrected to be:  brigadier
# coinbase  is corrected to be:  coinage
# namereg  is corrected to be:  namereg
# gitter  is corrected to be:  bitter
# ebay  is corrected to be:  bay
# wikipedia  is corrected to be:  wikipedia
# geth  is corrected to be:  get
# cuties  is corrected to be:  cities
# rube  is corrected to be:  rule
# jumple  is corrected to be:  jumble
# donsyang  is corrected to be:  donsyang
# localcoinswap  is corrected to be:  localcoinswap
# hackernews  is corrected to be:  hackernews
# hydrachain  is corrected to be:  hydrachain
# beckmans  is corrected to be:  beckman
# verizon  is corrected to be:  version
# snapchat  is corrected to be:  snapshot
# undeterminism  is corrected to be:  indeterminism
# coinmex  is corrected to be:  coined
# urls  is corrected to be:  curls
# permissionlessness  is corrected to be:  permissionlessness
# cointext  is corrected to be:  context
# bots  is corrected to be:  both
# sorries  is corrected to be:  worries
# cryptochicks  is corrected to be:  cryptochicks
# sayin  is corrected to be:  saying
# mandeleil  is corrected to be:  mandeleil
# mainnets  is corrected to be:  manners
# wechat  is corrected to be:  what
# sperb  is corrected to be:  superb
# paradex  is corrected to be:  parade
# sdks  is corrected to be:  sds
# swoosh  is corrected to be:  woosh
# huobi  is corrected to be:  hub
# rescan  is corrected to be:  rescue
# yann  is corrected to be:  ann
# prelaunch  is corrected to be:  relaunch
# hodled  is corrected to be:  howled
# zenginli  is corrected to be:  zenginli
# gamer  is corrected to be:  game
# olofsson  is corrected to be:  olsson
# antivirus  is corrected to be:  anti-virus
# resync  is corrected to be:  resent
# rekt  is corrected to be:  rest
# danielson  is corrected to be:  daniels
# tokenized  is corrected to be:  tokenized
# roundtable  is corrected to be:  round-table
# kakaotalk  is corrected to be:  kakaotalk
# naor  is corrected to be:  nor
# mati  is corrected to be:  mate
# bitangels  is corrected to be:  bitangels
# kevins  is corrected to be:  kevin
# iwallic  is corrected to be:  wallis
# limon  is corrected to be:  simon
# kipsen  is corrected to be:  kissed
# bylica  is corrected to be:  silica
# blockfolio  is corrected to be:  blockfolio
# bch  is corrected to be:  bc
# unbond  is corrected to be:  unbound
# cheddr  is corrected to be:  cheddar
# monetize  is corrected to be:  onetime
# sidecoin  is corrected to be:  side-on
# xbox  is corrected to be:  box
# seigniorage  is corrected to be:  seigniorage
# reorgs  is corrected to be:  reports
# bitrees  is corrected to be:  b-trees
# reddits  is corrected to be:  credits
# longfei  is corrected to be:  longer
# emoji  is corrected to be:  emosi
# skidanov  is corrected to be:  skidanov
# akiri  is corrected to be:  kiri
# staketx  is corrected to be:  stake
# bigquery  is corrected to be:  bigquery
# discontinues  is corrected to be:  discontinued
# junge  is corrected to be:  june
# ontologynetwork  is corrected to be:  ontologynetwork
# istitution  is corrected to be:  institution
# onboarded  is corrected to be:  boarded
# antonopoulos  is corrected to be:  antonopoulos
# nikkor  is corrected to be:  nikko
# steemit  is corrected to be:  steenie
# lorien  is corrected to be:  loren
# erienced  is corrected to be:  oriented
# dappchain  is corrected to be:  dappchain
# usdt  is corrected to be:  udt
# quantstamp  is corrected to be:  quantstamp
# cker  is corrected to be:  cher
# junco  is corrected to be:  juno
# nq  is corrected to be:  no
# json  is corrected to be:  son
# kodebox  is corrected to be:  kodebox
# kapoof  is corrected to be:  kapoor
# checkmark  is corrected to be:  checkmate
# econotimes  is corrected to be:  economies
# gamaroff  is corrected to be:  gamaroff
# facebook  is corrected to be:  casebook
# defi  is corrected to be:  defy
# rlp  is corrected to be:  lp
# copay  is corrected to be:  copy
# hanwha  is corrected to be:  hannah
# delst  is corrected to be:  delft
# indodax  is corrected to be:  indodax
# tlsnotary  is corrected to be:  tlsnotary
# ecip  is corrected to be:  cip
# lixin  is corrected to be:  living
# faqs  is corrected to be:  fans
# fpga  is corrected to be:  pga
# cointime  is corrected to be:  coincide
# tweeted  is corrected to be:  tweeter
# codewise  is corrected to be:  codeine
# spectate  is corrected to be:  spectacle
# xchain  is corrected to be:  chain
# unbox  is corrected to be:  union
# bianjie  is corrected to be:  binkie
# astroturfers  is corrected to be:  astroturfers
# unwow  is corrected to be:  now
# kudryatsev  is corrected to be:  kudryatsev
# succes  is corrected to be:  success
# etcgame  is corrected to be:  endgame
# icos  is corrected to be:  cos
# ressed  is corrected to be:  dressed
# upnp  is corrected to be:  pnp
# honeybadger  is corrected to be:  honeybadger
# iban  is corrected to be:  ian
# altcoin  is corrected to be:  alton
# pocs  is corrected to be:  pots
# multisig  is corrected to be:  multisig
# paybito  is corrected to be:  partito
# yuanbao  is corrected to be:  yuanbao
# egifter  is corrected to be:  register
# eris  is corrected to be:  eric
# pyethereum  is corrected to be:  pyethereum
# emacs  is corrected to be:  macs
# ofir  is corrected to be:  fir
# usal  is corrected to be:  usual
# mossid  is corrected to be:  mossad
# ellena  is corrected to be:  ellen
# rainmaker  is corrected to be:  rainwater
# websocket  is corrected to be:  websocket
# familiy  is corrected to be:  family
# memecraft  is corrected to be:  memecraft
# loring  is corrected to be:  losing
# quora  is corrected to be:  quota
# req  is corrected to be:  red
# aud  is corrected to be:  and
# lanation  is corrected to be:  planation
# infura  is corrected to be:  infra
# easycheers  is corrected to be:  easycheers
# metacoin  is corrected to be:  metazoan
# workarounds  is corrected to be:  workarounds
# birthed  is corrected to be:  berthed
# danhua  is corrected to be:  dana
# blockchains  is corrected to be:  blockchains
# ressing  is corrected to be:  pressing
# bitfinex  is corrected to be:  riofinex
# firewall  is corrected to be:  fireball
# ridesharing  is corrected to be:  ridesharing
# okex  is corrected to be:  obex
# upbit  is corrected to be:  a bit
# toshi  is corrected to be:  tosh
# complet  is corrected to be:  complete
# silentpanther  is corrected to be:  silentpanther
# lorers  is corrected to be:  lovers
# timeout  is corrected to be:  time-out
# cyano  is corrected to be:  cyrano
# treehouse  is corrected to be:  tree-house
# ression  is corrected to be:  session
# dvlprs  is corrected to be:  delors
# qml  is corrected to be:  ml
# etherscripter  is corrected to be:  etherscripter
# startupdebut  is corrected to be:  startupdebut
# bter  is corrected to be:  beer
# bitkan  is corrected to be:  bitten
# purrduce  is corrected to be:  produce
# quanttek  is corrected to be:  quantock
# mkt  is corrected to be:  met
# phantasma  is corrected to be:  phantasm
# alot  is corrected to be:  a lot
# specialk  is corrected to be:  special
# pumpers  is corrected to be:  jumpers
# backlogged  is corrected to be:  backlogged
# digitalizes  is corrected to be:  digitalis
# feces  is corrected to be:  faces
# nnt  is corrected to be:  not
# gethy  is corrected to be:  getty
# rockstar  is corrected to be:  rockstar
# fwd  is corrected to be:  fed
# multidoge  is corrected to be:  multimode
# dappchains  is corrected to be:  dappchains
# sensetime  is corrected to be:  sensitive
# kotti  is corrected to be:  gotti
# paycheck  is corrected to be:  pacheco
# satoshis  is corrected to be:  satoshis
# deltec  is corrected to be:  deltic
# ...
# suzhou  is corrected to be:  shou
# moviebloc  is corrected to be:  moviebloc
# atls  is corrected to be:  atlas
# erights  is corrected to be:  rights
# bobsled  is corrected to be:  bobbled
# openapi  is corrected to be:  openup
# moonshot  is corrected to be:  moonshot
# cryptofast  is corrected to be:  cryptofast
# mainnet  is corrected to be:  manner
# emails  is corrected to be:  email
# cryptocurrency  is corrected to be:  cryptocurrency
# bitswap  is corrected to be:  bitmap
# arenarius  is corrected to be:  denarius
# golang  is corrected to be:  golan
# halong  is corrected to be:  along
# timezones  is corrected to be:  time-zones
# laika  is corrected to be:  lanka
# coinloan  is corrected to be:  conlon
# galaxus  is corrected to be:  galaxy
# vitalik  is corrected to be:  vitali
# ccss  is corrected to be:  cass
# ironpython  is corrected to be:  ironpython
# visualizer  is corrected to be:  visualize
# fueled  is corrected to be:  fuelled
# bitcoin  is corrected to be:  hitchin
# talladega  is corrected to be:  talladega
# wif  is corrected to be:  if
# debug  is corrected to be:  debut
# openbazaar  is corrected to be:  openbazaar
# tradeoffs  is corrected to be:  trade-offs
# ethsingaporeseminar  is corrected to be:  ethsingaporeseminar
# checksums  is corrected to be:  checksum
# bountied  is corrected to be:  bounties
# graphene  is corrected to be:  grapheme
# blockchain  is corrected to be:  blockchain
# klepatch  is corrected to be:  eyepatch
# retweets  is corrected to be:  retreats
# etheria  is corrected to be:  etheric
# rong  is corrected to be:  long
# holla  is corrected to be:  holly
# armored  is corrected to be:  armoured
# becze  is corrected to be:  becke
# shantou  is corrected to be:  shannon
# peronet  is corrected to be:  percent
# belane  is corrected to be:  beltane
# lianan  is corrected to be:  lionan
# ideation  is corrected to be:  creation
# huuge  is corrected to be:  huge
# modeled  is corrected to be:  modelled
# niran  is corrected to be:  iran
# attn  is corrected to be:  att
# dpos  is corrected to be:  dos
# lightdb  is corrected to be:  light
# infos  is corrected to be:  info
# tnabc  is corrected to be:  abc
# decentralizer  is corrected to be:  decentralized
# mushegian  is corrected to be:  mushegian
# jpy  is corrected to be:  joy
# evm  is corrected to be:  erm
# ipfs  is corrected to be:  ifs
# meetups  is corrected to be:  meets
# monero  is corrected to be:  monro
# autoblocked  is corrected to be:  autoblocked
# symb  is corrected to be:  syms
# mmhmm  is corrected to be:  mmmm
# ete  is corrected to be:  eye
# ipad  is corrected to be:  pad
# gpus  is corrected to be:  gps
# msgs  is corrected to be:  mugs
# throwdown  is corrected to be:  showdown
# augurnetwork  is corrected to be:  augurnetwork
# aliivee  is corrected to be:  alive
# bledel  is corrected to be:  level
# sikorka  is corrected to be:  sikora
# kansans  is corrected to be:  kansas
# inbetween  is corrected to be:  in between
# toolchain  is corrected to be:  toolchain
# cryptosphere  is corrected to be:  cryptosphere
# uajs  is corrected to be:  uaps
# dji  is corrected to be:  di
# cto  is corrected to be:  to
# wrkshp  is corrected to be:  workshop
# aplicaciones  is corrected to be:  aplicaciones
# seo  is corrected to be:  so
# async  is corrected to be:  sync
# financieras  is corrected to be:  financiers
# realcoin  is corrected to be:  realcoin
# honglei  is corrected to be:  longley
# trustless  is corrected to be:  trustees
# ontrade  is corrected to be:  trade
# dvp  is corrected to be:  dip
# spass  is corrected to be:  pass
# illinoisans  is corrected to be:  illinoisans
# schoedon  is corrected to be:  schoon
# freeh  is corrected to be:  free
# ubuntu  is corrected to be:  bantu
# chikara  is corrected to be:  chiara
# firewalled  is corrected to be:  firewalled
# originalmy  is corrected to be:  originally
# pauseable  is corrected to be:  passable
# lavasnow  is corrected to be:  lavasnow
# glhfdd  is corrected to be:  glhfdd
# loited  is corrected to be:  looted
# meltem  is corrected to be:  melted
# venezuelans  is corrected to be:  venezuelan
# seberino  is corrected to be:  sobering
# banko  is corrected to be:  bank
# stakable  is corrected to be:  stable
# tweetstorm  is corrected to be:  tweetstorm
# yaz  is corrected to be:  ya
# connectable  is corrected to be:  contestable
# crowdsales  is corrected to be:  crowdsales
# carsten  is corrected to be:  karsten
# spamming  is corrected to be:  slamming
# sputnikvm  is corrected to be:  sputnik
# jobtribes  is corrected to be:  jobtribes
# fulfills  is corrected to be:  fulfils
# bodog  is corrected to be:  bodo
# windex  is corrected to be:  index
# coinsquare  is corrected to be:  chi-square
# bootcamp  is corrected to be:  bootham
# css  is corrected to be:  cos
# blog  is corrected to be:  blow
# kayvon  is corrected to be:  avon
# pornhub  is corrected to be:  pornhub
# custdoain  is corrected to be:  custodian
# homepage  is corrected to be:  homage
# emba  is corrected to be:  emma
# fmr  is corrected to be:  for
# stucks  is corrected to be:  stuck
# truthcoin  is corrected to be:  truthcoin
# daytraders  is corrected to be:  daytraders
# tooltip  is corrected to be:  toolkit
# idealondon  is corrected to be:  idealondon
# sworm  is corrected to be:  storm
# cashback  is corrected to be:  flashback
# signaling  is corrected to be:  signalling
# collectibles  is corrected to be:  collectables
# techcrunch  is corrected to be:  techcrunch
# retryable  is corrected to be:  repayable
# metalab  is corrected to be:  metal
# loreaugur  is corrected to be:  loreaugur
# beosin  is corrected to be:  eosin
# devrelcon  is corrected to be:  devrelcon
# dacs  is corrected to be:  days
# buterin  is corrected to be:  butlin
# bittrex  is corrected to be:  bitrex
# thedao  is corrected to be:  theda
# rawr  is corrected to be:  raw
# dht  is corrected to be:  dot
# ning  is corrected to be:  king
# delists  is corrected to be:  deists
# turboethereum  is corrected to be:  turboethereum
# kibayashi  is corrected to be:  kibayashi
# unbinding  is corrected to be:  unwinding
# iov  is corrected to be:  iv
# testnet  is corrected to be:  tested
# usd  is corrected to be:  us
# kenetic  is corrected to be:  genetic
# erfrort  is corrected to be:  effort
# faq  is corrected to be:  far
# haudenschild  is corrected to be:  haudenschild
# ddos  is corrected to be:  dos
# tokenbridge  is corrected to be:  tonbridge
# patreon  is corrected to be:  patron
# bribable  is corrected to be:  probable
# xcpc  is corrected to be:  cpc
# paritygame  is corrected to be:  paritygame
# dubble  is corrected to be:  bubble
# garners  is corrected to be:  earners
# qixi  is corrected to be:  ixi
# lerider  is corrected to be:  leader
# bitpay  is corrected to be:  biopsy
# retweeting  is corrected to be:  retreating
# mycrypto  is corrected to be:  mycrypto
# rebranded  is corrected to be:  remanded
# moneybutton  is corrected to be:  moneybutton
# idr  is corrected to be:  dr
# blkchain  is corrected to be:  lochain
# matan  is corrected to be:  satan
# jiaying  is corrected to be:  saying
# uesd  is corrected to be:  used
# peercover  is corrected to be:  peercover
# hamsterpad  is corrected to be:  hamsterpad
# puey  is corrected to be:  prey
# panews  is corrected to be:  panels
# sandboxed  is corrected to be:  sandboxed
# bruh  is corrected to be:  brush
# chainers  is corrected to be:  chairs
# nft  is corrected to be:  not
# disincentivize  is corrected to be:  disincentive
# buidl  is corrected to be:  build
# smartxbeta  is corrected to be:  smartxbeta
# neocontract  is corrected to be:  neocontract
# smtchecker  is corrected to be:  smtchecker
# jillette  is corrected to be:  gillette
# coms  is corrected to be:  come
# avatars  is corrected to be:  altars
# debunks  is corrected to be:  debunk
# xtoken  is corrected to be:  token
# andresen  is corrected to be:  andersen
# testrpc  is corrected to be:  testrpc
# dapi  is corrected to be:  dai
# noncustodial  is corrected to be:  non-custodial
# hangouts  is corrected to be:  handouts
# masterbranch  is corrected to be:  masterbranch
# microtransactions  is corrected to be:  microtransactions
# hackathons  is corrected to be:  hackathons
# etherception  is corrected to be:  etherception
# arnd  is corrected to be:  and
# aths  is corrected to be:  paths
# ethereums  is corrected to be:  ethereums
# omisego  is corrected to be:  omisego
# blogger  is corrected to be:  logger
# relayer  is corrected to be:  relayed
# webinar  is corrected to be:  seminar
# dogesled  is corrected to be:  digested
# prohect  is corrected to be:  project
# crowdsale  is corrected to be:  croxdale
# ethstats  is corrected to be:  ethstats
# yongxin  is corrected to be:  yongxin
# litecoin  is corrected to be:  litecoin
# paywall  is corrected to be:  payroll
# mempool  is corrected to be:  mempool
# woocommerce  is corrected to be:  woocommerce
# npm  is corrected to be:  pm
# spaceflight  is corrected to be:  spaceflight
# vicurex  is corrected to be:  vicurex
# heiko  is corrected to be:  meiko
# lundkvist  is corrected to be:  lundqvist
# prototyped  is corrected to be:  prototype
# rearchitecting  is corrected to be:  rearchitecting
# collison  is corrected to be:  collision
# digitec  is corrected to be:  digitech
# ailurophilia  is corrected to be:  ailurophilia
# gitbook  is corrected to be:  gitbook
# pallar  is corrected to be:  pillar
# wsj  is corrected to be:  ws
# composability  is corrected to be:  comparability
# zeniex  is corrected to be:  denied
# lilic  is corrected to be:  lili
# neoworld  is corrected to be:  networld
# antifragility  is corrected to be:  antifragility
# meetup  is corrected to be:  meet
# dogecoin  is corrected to be:  dogecoin
# rting  is corrected to be:  ring
# nentially  is corrected to be:  mentally
# kryptosf  is corrected to be:  krypton
# backend  is corrected to be:  backed
# assistd  is corrected to be:  assist
# deeponion  is corrected to be:  deeponion
# raiden  is corrected to be:  maiden
# signups  is corrected to be:  signs
# zuckenberg  is corrected to be:  zuckenberg
# christien  is corrected to be:  christian
# ellithorpe  is corrected to be:  ellithorpe
# bitclubnetwork  is corrected to be:  bitclubnetwork
# antshares  is corrected to be:  antares
# nist  is corrected to be:  list
# scamcoin  is corrected to be:  scamcoin
# dbft  is corrected to be:  daft
# writeup  is corrected to be:  write-up
# vyper  is corrected to be:  viper
# mcgethface  is corrected to be:  mcgethface
# ethereum  is corrected to be:  ethereal
# tapscott  is corrected to be:  talcott
# developability  is corrected to be:  developability
# metadata  is corrected to be:  teradata
# outduels  is corrected to be:  outduels
# buzzfeed  is corrected to be:  buzzed
# mortem  is corrected to be:  morte
# technode  is corrected to be:  techno
# zksnarks  is corrected to be:  zksnarks
# megrez  is corrected to be:  degree
# crowdfunding  is corrected to be:  crowdfunding
# vogelstellar  is corrected to be:  vogelstellar
# marketplaces  is corrected to be:  marketplace
# meti  is corrected to be:  met
# ecurity  is corrected to be:  security
# neofs  is corrected to be:  neons
# peeratlas  is corrected to be:  peeratlas
# ehlert  is corrected to be:  ehlers
# scalabilility  is corrected to be:  scalability
# liveness  is corrected to be:  likeness
# ronns  is corrected to be:  ronni
# oge  is corrected to be:  one
# progpow  is corrected to be:  progpow
# oklahomans  is corrected to be:  oklahoma
# avg  is corrected to be:  ag
# gdax  is corrected to be:  gda
# initializing  is corrected to be:  initializing
# beauregard  is corrected to be:  beauregard
# fud  is corrected to be:  fund
# dappzone  is corrected to be:  dappzone
# localbitcoins  is corrected to be:  localbitcoins
# whops  is corrected to be:  shops
# kbgs  is corrected to be:  bgs
# yasen  is corrected to be:  rasen
# sia  is corrected to be:  six
# qihoo  is corrected to be:  hoo
# zug  is corrected to be:  dug
# btc  is corrected to be:  etc
# bitcoinxt  is corrected to be:  bitcoinxt
# tumblr  is corrected to be:  tumble
# youtubers  is corrected to be:  youtubers
# vdfs  is corrected to be:  vdus
# diffie  is corrected to be:  diffi
# yakobovitch  is corrected to be:  yakobovitch
# jae  is corrected to be:  joe
# pix  is corrected to be:  six
# ethereumclassicnetwork  is corrected to be:  ethereumclassicnetwork
# baad  is corrected to be:  bad
# decal  is corrected to be:  deal
# etherex  is corrected to be:  there
# zhejiang  is corrected to be:  zhejiang
# permissionless  is corrected to be:  permissionless
# conf  is corrected to be:  con
# ethercluster  is corrected to be:  ethercluster
# shiba  is corrected to be:  shia
# theymos  is corrected to be:  thermos
# leverages  is corrected to be:  leverage
# meh  is corrected to be:  me
# evms  is corrected to be:  vms
# usernames  is corrected to be:  username
# guesser  is corrected to be:  guessed
# jeweler  is corrected to be:  jeweller
# cobo  is corrected to be:  combo
# sharevolume  is corrected to be:  sharevolume
# gozaimasu  is corrected to be:  gozaimasu
# fishchain  is corrected to be:  fishchain
# allive  is corrected to be:  alive
# newegg  is corrected to be:  newer
# rons  is corrected to be:  runs
# pvp  is corrected to be:  pop
# petterson  is corrected to be:  patterson
# starip  is corrected to be:  strip
# vrex  is corrected to be:  rex
# latamex  is corrected to be:  latimer
# atoken  is corrected to be:  token
# swych  is corrected to be:  stych
# optimizer  is corrected to be:  optimize
# ert  is corrected to be:  er
# gox  is corrected to be:  got
# contrib  is corrected to be:  control
# statechannels  is corrected to be:  statechannels
# daos  is corrected to be:  days
# fintechlab  is corrected to be:  fintechlab
# triones  is corrected to be:  tries
# mgmt  is corrected to be:  gmt
# heslinki  is corrected to be:  helsinki
# uniswap  is corrected to be:  uniswap
# kovan  is corrected to be:  koran
# emojis  is corrected to be:  emosi
# wilke  is corrected to be:  wilko
# actoress  is corrected to be:  actress
# dcg  is corrected to be:  dog
# grothendieck  is corrected to be:  grothendieck
# geekhub  is corrected to be:  geekhub
# netflix  is corrected to be:  netflix
# obfuscated  is corrected to be:  obfuscated
# chainhop  is corrected to be:  chainhop
# hardfork  is corrected to be:  hardcore
# rli  is corrected to be:  ali
# asare  is corrected to be:  aware
# sasb  is corrected to be:  sas
# seraph  is corrected to be:  search
# trilemma  is corrected to be:  dilemma
# bessere  is corrected to be:  lesser
# debunked  is corrected to be:  rebuked
# cashshuffle  is corrected to be:  cashshuffle
# optimizations  is corrected to be:  optimization
# cex  is corrected to be:  sex
# missteps  is corrected to be:  misses
# ullivan  is corrected to be:  sullivan
# ires  is corrected to be:  fires
# baidu  is corrected to be:  bahdu
# asicboost  is corrected to be:  asicboost
# dilluting  is corrected to be:  diluting
# cynophile  is corrected to be:  cynophile
# antiatoms  is corrected to be:  antiatoms
# bailout  is corrected to be:  bail-out
# ethdev  is corrected to be:  ethel
# brigaded  is corrected to be:  brigade
# lainer  is corrected to be:  liner
# tennesseans  is corrected to be:  tennesseans
# teex  is corrected to be:  tee
# etr  is corrected to be:  er
# eosio  is corrected to be:  eosin
# poloniex  is corrected to be:  colonies
# alchemint  is corrected to be:  alchemist
# openrpc  is corrected to be:  openup
# rivaled  is corrected to be:  rivalled
# lubinets  is corrected to be:  cabinets
# borderless  is corrected to be:  borderers
# whitelist  is corrected to be:  hit-list
# shilled  is corrected to be:  skilled
# repelying  is corrected to be:  replying
# microchains  is corrected to be:  microchips
# sakich  is corrected to be:  stich
# detrio  is corrected to be:  detail
# tendermint  is corrected to be:  tendering
# radex  is corrected to be:  radek
# cognizant  is corrected to be:  cognisant
# roundtablemeeting  is corrected to be:  roundtablemeeting
# losion  is corrected to be:  lesion
# simonsson  is corrected to be:  simonsen
# laining  is corrected to be:  gaining
# kindaichi  is corrected to be:  kindaichi
# sockpuppet  is corrected to be:  sockpuppet
# detials  is corrected to be:  details
# metamask  is corrected to be:  metamask
# hoodie  is corrected to be:  moodie
# blitzpredict  is corrected to be:  blitzpredict
# tsinghua  is corrected to be:  tsinghua
# acg  is corrected to be:  act
# dogecoins  is corrected to be:  dogecoins
# dionysis  is corrected to be:  dionysius

# %% [markdown]
# #### after browsing the modification list, I manually decide these spelling checks are valid:
# aand is corrected to be:  and
# gettin	is	corrected	to	be:	getting
# yez is	corrected	to	be:	yes
# aliivee is	corrected	to	be:	alive
# fiire  is	corrected	to	be:	fire
# huuge is	corrected	to	be:	huge
# waay  is	corrected	to	be:	way

# %%
# modify bag_of_words_dict_1

transfer_dict = {'aand':'and','gettin':'getting','yez':'yes','fiire':'fire','huuge':'huge','waay':'way'}
for key,value in bag_of_words_dict_1.items():
    if value in list(transfer_dict.keys()):
        bag_of_words_dict_1[key] = transfer_dict[value]
        print(key,"->",transfer_dict[value])
# Out:
# fiiiiire -> fire
# gettin -> getting
# huuuuuge -> huge
# waaay -> way
# yez -> yes

# %% [markdown]
# # Section C: for 10069 words, do stemming
# https://www.datacamp.com/community/tutorials/stemming-lemmatization-python
# Stemming is the process of reducing inflection in words to their root forms such as mapping a group of words to the same stem even if the stem itself is not a valid word in the Language.

# %%
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> punkt
# Command 'punkt' unrecognized
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> punkt
#     Downloading package punkt to /home/zhiyuan8/nltk_data...
#       Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %% [markdown]
# ## C-1 run tutorial
# https://www.datacamp.com/community/tutorials/stemming-lemmatization-python

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
#create an object of class PorterStemmer
porter = PorterStemmer() # PorterStemmer is known for its simplicity and speed
lancaster=LancasterStemmer()
#proide a word to be stemmed
print("Porter Stemmer:")
print(porter.stem("cats"))
print(porter.stem("trouble"))
print(porter.stem("troubling"))
print(porter.stem("troubled"))
print("Lancaster Stemmer:")
print(lancaster.stem("cats"))
print(lancaster.stem("trouble"))
print(lancaster.stem("troubling"))
print(lancaster.stem("troubled"))
# Out:
# Porter Stemmer
# cat
# troubl
# troubl
# troubl
# Lancaster Stemmer
# cat
# troubl
# troubl
# troubl

# %%
#A list of words to be stemmed

'''
PorterStemmer is known for its simplicity and speed. 
It is commonly useful in Information Retrieval Environments known as IR Environments 
for fast recall and fetching of search queries.
'''
word_list = ["friend", "friendship", "friends", "friendships","stabil","destabilize","misunderstanding","railroad","moonlight","football"]
print("{0:20}{1:20}{2:20}".format("Original Word:","Porter Stemmer:","lancaster Stemmer:"))
for word in word_list:
    print("{0:20}{1:20}{2:20}".format(word,porter.stem(word),lancaster.stem(word)))
# Out:
# Original Word:      Porter Stemmer:     lancaster Stemmer:
# friend              friend              friend
# friendship          friendship          friend
# friends             friend              friend
# friendships         friendship          friend
# stabil              stabil              stabl
# destabilize         destabil            dest
# misunderstanding    misunderstand       misunderstand
# railroad            railroad            railroad
# moonlight           moonlight           moonlight
# football            footbal             footbal

# %%
# stem sentences
sentence="Pythoners are very intelligent and work very pythonly and now they are pythoning their way to success."
porter.stem(sentence)
# Out:
# 'pythoners are very intelligent and work very pythonly and now they are pythoning their way to success.'

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
def stemSentence(sentence):
    token_words=word_tokenize(sentence)
    token_words
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

x=stemSentence(sentence)
print(x)
# Out:
# python are veri intellig and work veri pythonli and now they are python their way to success .

# %% [markdown]
# ## C-main run stemming, create a map between stemmed and original words

# %%
print(len(bag_of_words_dict_1)) # use bag_of_words_dict_1 here
# Out:
# 10069

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer() # PorterStemmer is known for its simplicity and speed
bag_of_words_dict_2 = dict() # save value of bag_of_words_dict_1 as of key bag_of_words_dict_2

for key,value in bag_of_words_dict_1.items():
    word = value
    word_stem = porter.stem(word)
    
    if word_stem not in list(bag_of_words_dict_2.keys()): # cannot find stem in key list
        bag_of_words_dict_2.update({ word_stem:[word] })
    else: # find stem in key list
        bag_of_words_dict_2[word_stem].append(word)
    
    if key != value: # for example, key = huuuuge, value = huge, then add hugh & huuuuge to dict
        bag_of_words_dict_2[word_stem].append(key)

# %%
bag_of_words_dict_2
# Out:
# {'and': ['and', 'aaand', 'anded', 'anding', 'ands'],
#  'abandon': ['abandon', 'abandoned', 'abandonment'],
#  'abc': ['abc'],
#  'abe': ['abe'],
#  'abi': ['abi'],
#  'abil': ['ability'],
#  'abl': ['able'],
#  'aboard': ['aboard'],
#  'abolit': ['abolition'],
#  'abra': ['abra'],
#  'abroad': ['abroad'],
#  'abruptli': ['abruptly'],
#  'absent': ['absent'],
#  'absolut': ['absolute', 'absolutely'],
#  'abstract': ['abstract', 'abstracted', 'abstraction'],
#  'absurd': ['absurd', 'absurdity'],
#  'abt': ['abt'],
#  'abus': ['abusing', 'abusive'],
#  'abuzz': ['abuzz'],
#  'academ': ['academic', 'academics'],
#  'academi': ['academy'],
#  'acceler': ['accelerate', 'accelerates', 'accelerating', 'accelerator'],
#  'accept': ['accept',
#   'acceptable',
#   'acceptance',
#   'accepted',
#   'accepting',
#   'accepts'],
#  'access': ['access', 'accessed', 'accessibility', 'accessible', 'accessing'],
#  'accident': ['accidentally'],
#  'accid': ['accidents'],
#  'acclaim': ['acclaim'],
#  'accommod': ['accommodate'],
#  'accompani': ['accompanying'],
#  'accomplish': ['accomplished', 'accomplishment', 'accomplishments'],
#  'accord': ['accord', 'accordance', 'according'],
#  'accordingli': ['accordingly'],
#  'account': ['account', 'accountability', 'accounting', 'accounts'],
#  'accredit': ['accredited'],
#  'accrual': ['accrual'],
#  'accumul': ['accumulates'],
#  'accuraci': ['accuracy'],
#  'accur': ['accurate', 'accurately'],
#  'accus': ['accusation', 'accusations', 'accuse'],
#  'ace': ['ace'],
#  'acg': ['acg'],
#  'achiev': ['achievable', 'achieve', 'achieved', 'achieving'],
#  'acknowledg': ['acknowledging'],
#  'acquir': ['acquired', 'acquires'],
#  'acquisit': ['acquisition', 'acquisitions'],
#  'across': ['across'],
#  'act': ['act', 'acting'],
#  'action': ['action', 'actions'],
#  'activ': ['activate',
#   'activated',
#   'activating',
#   'activation',
#   'active',
#   'actively',
#   'activities',
#   'activity'],
#  'actor': ['actor', 'actors'],
#  'actoress': ['actoress'],
#  'actress': ['actress'],
#  'actual': ['actual', 'actually'],
#  'actu': ['actus'],
#  'ad': ['ad', 'added', 'adding'],
#  'ada': ['ada'],
#  'adapt': ['adapt', 'adapting', 'adaptive'],
#  'add': ['add', 'adds'],
#  'addit': ['addition', 'additional', 'additionally', 'additions', 'additive'],
#  'address': ['address', 'addressable', 'addressed', 'addresses', 'addressing'],
#  'adept': ['adept'],
#  'adequ': ['adequate'],
#  'adex': ['adex'],
#  'adher': ['adhere', 'adheres', 'adhering'],
#  'adi': ['adi'],
#  'adjust': ['adjustments'],
#  'admin': ['admin', 'admins'],
#  'admit': ['admit'],
#  'adopt': ['adopt', 'adopted', 'adopters', 'adopting', 'adoption', 'adopts'],
#  'ador': ['adorable'],
#  'adrealm': ['adrealm'],
#  'adrenalin': ['adrenaline'],
#  'adtech': ['adtech'],
#  'adult': ['adults'],
#  'advanc': ['advance',
#   'advanced',
#   'advancement',
#   'advancements',
#   'advances',
#   'advancing'],
#  'advani': ['advani'],
#  'advantag': ['advantage', 'advantages'],
#  'advent': ['advent'],
#  'adventur': ['adventure', 'adventures'],
#  'adversari': ['adversarial'],
#  'advertis': ['advertised', 'advertisement', 'advertising'],
#  'advic': ['advice'],
#  'advis': ['advise', 'advised', 'advises'],
#  'advisor': ['advisor', 'advisors'],
#  'advisori': ['advisory'],
#  'advocaci': ['advocacy'],
#  'advoc': ['advocate', 'advocates', 'advocating'],
#  'aeron': ['aeron'],
#  'aerospac': ['aerospace'],
#  'afaik': ['afaik'],
#  'affair': ['affairs'],
#  'affect': ['affected', 'affecting', 'affects'],
#  'affili': ['affiliate', 'affiliated', 'affiliates', 'affiliations'],
#  'afford': ['afford', 'affords'],
#  'afk': ['afk'],
#  'afraid': ['afraid'],
#  'afri': ['afri'],
#  'africa': ['africa'],
#  'african': ['african'],
#  'afternoon': ['afternoon'],
#  'afterparti': ['afterparties', 'afterparty'],
#  'ag': ['ag'],
#  'age': ['age'],
#  'agenda': ['agenda'],
#  'agent': ['agent'],
#  'aggreg': ['aggregated',
#   'aggregates',
#   'aggregating',
#   'aggregation',
#   'aggregator',
#   'aggregators'],
#  'aggress': ['aggressively'],
#  'agharta': ['agharta'],
#  'agnost': ['agnostic'],
#  'ago': ['ago'],
#  'agre': ['agree', 'agreed', 'agrees'],
#  'agreement': ['agreement', 'agreements'],
#  'agrello': ['agrello'],
#  'agyei': ['agyei'],
#  'ahead': ['ahead'],
#  'ai': ['ai'],
#  'aid': ['aid'],
#  'aiden': ['aiden'],
#  'ailurophilia': ['ailurophilia'],
#  'aim': ['aim', 'aimed', 'aiming', 'aims'],
#  'air': ['air', 'aired', 'airing'],
#  'airbitz': ['airbitz'],
#  'airdrop': ['airdrop', 'airdropped', 'airdropping', 'airdrops'],
#  'airlin': ['airline'],
#  'airlock': ['airlock'],
#  'airport': ['airport'],
#  'ajout': ['ajoutes'],
#  'aka': ['aka'],
#  'akiri': ['akiri'],
#  'akomba': ['akomba'],
#  'al': ['al'],
#  'alabamian': ['alabamians'],
#  'alan': ['alan'],
#  'alarm': ['alarm', 'alarming', 'alarms'],
#  'alaskan': ['alaskans'],
#  'alchemint': ['alchemint'],
#  'alchemi': ['alchemy'],
#  'alephzero': ['alephzero'],
#  'alert': ['alert', 'alerting'],
#  'alethzero': ['alethzero'],
#  'alex': ['alex'],
#  'alexaki': ['alexakis'],
#  'alexand': ['alexander'],
#  'alexandra': ['alexandra'],
#  'alexi': ['alexis'],
#  'algo': ['algo', 'algos'],
#  'algorithm': ['algorithm', 'algorithmic', 'algorithms'],
#  'alic': ['alice'],
#  'alien': ['aliens'],
#  'align': ['aligned', 'aligning', 'alignment'],
#  'aliive': ['aliivee', 'aliiiiveee'],
#  'alik': ['alike'],
#  'alioth': ['alioth'],
#  'alison': ['alison', 'alisons'],
#  'aliv': ['alive'],
#  'alkaid': ['alkaid'],
#  'alleg': ['allegations', 'alleged'],
#  'allegedli': ['allegedly'],
#  'allegor': ['allegorical'],
#  'allen': ['allen'],
#  'alley': ['alley'],
#  'allianc': ['alliance'],
#  'alli': ['allied'],
#  'alliv': ['allive'],
#  'alloc': ['allocated', 'allocation', 'allocations'],
#  'allow': ['allow', 'allowed', 'allowing', 'allows'],
#  'alluma': ['alluma'],
#  'almost': ['almost'],
#  'alon': ['alone'],
#  'along': ['along'],
#  'alongsid': ['alongside'],
#  'alot': ['alot'],
#  'alpha': ['alpha'],
#  'alphabet': ['alphabetical'],
#  'alreadi': ['already'],
#  'alright': ['alright'],
#  'alsindi': ['alsindi'],
#  'also': ['also'],
#  'altcoin': ['altcoin', 'altcoins'],
#  'alten': ['altenative'],
#  'alter': ['alter', 'altered'],
#  'altern': ['alternate', 'alternative', 'alternatives'],
#  'although': ['although'],
#  'altogeth': ['altogether'],
#  'alt': ['alts'],
#  'alum': ['alum'],
#  'alway': ['always'],
#  'ama': ['ama', 'amas'],
#  'amauri': ['amaury'],
#  'amaz': ['amaze', 'amazing'],
#  'amazingli': ['amazingly'],
#  'amazon': ['amazon'],
#  'ambassador': ['ambassador', 'ambassadors'],
#  'ambient': ['ambients'],
#  'ambit': ['ambitions'],
#  'ambiti': ['ambitious'],
#  'ambush': ['ambushes'],
#  'amend': ['amended'],
#  'america': ['america', 'americas'],
#  'american': ['american', 'americans'],
#  'americana': ['americana'],
#  'amid': ['amid'],
#  'amidst': ['amidst'],
#  'amigo': ['amigos'],
#  'amir': ['amir'],
#  'aml': ['aml'],
#  'among': ['among'],
#  'amongst': ['amongst'],
#  'amount': ['amount', 'amounts'],
#  'amp': ['amp'],
#  'amphibi': ['amphibious'],
#  'amplifi': ['amplified'],
#  'amsterdam': ['amsterdam'],
#  'amus': ['amused', 'amusement', 'amusing'],
#  'analog': ['analoge', 'analogies', 'analogy'],
#  'analysi': ['analysis'],
#  'analyst': ['analyst'],
#  'analyt': ['analytic', 'analytical', 'analytics'],
#  'analyz': ['analyze', 'analyzed', 'analyzes', 'analyzing'],
#  'ananya': ['ananya'],
#  'anarchapulco': ['anarchapulco'],
#  'anatoli': ['anatoly'],
#  'anc': ['anc'],
#  'anchor': ['anchors'],
#  'ancillari': ['ancillary'],
#  'andr': ['andr', 'andre'],
#  'andrea': ['andreas'],
#  'andrei': ['andrei'],
#  'andresen': ['andresen'],
#  'andrew': ['andrew'],
#  'android': ['android'],
#  'andi': ['andy'],
#  'angel': ['angeles'],
#  'anger': ['angered'],
#  'angri': ['angry'],
#  'anim': ['animated', 'animation'],
#  'animaz': ['animazing'],
#  'ann': ['ann'],
#  'anniversari': ['anniversary'],
#  'anniversasri': ['anniversasry'],
#  'annouc': ['annouce'],
#  'announc': ['announce',
#   'announced',
#   'announcement',
#   'announcements',
#   'announces',
#   'announcing'],
#  'annoy': ['annoyed'],
#  'annual': ['annual'],
#  'anomali': ['anomaly'],
#  'anon': ['anon'],
#  'anonym': ['anonymity', 'anonymous'],
#  'anoth': ['another'],
#  'an': ['ans'],
#  'ansion': ['ansion'],
#  'answer': ['answer', 'answered', 'answering', 'answers'],
#  'antagonist': ['antagonistic'],
#  'anthoni': ['anthony', 'anthonys'],
#  'anti': ['anti'],
#  'antiatom': ['antiatoms'],
#  'anticip': ['anticipate', 'anticipated', 'anticipating', 'anticipation'],
#  'antifragil': ['antifragility'],
#  'antiviru': ['antivirus'],
#  'antmin': ['antminer'],
#  'antonopoulo': ['antonopoulos'],
#  'antpool': ['antpool'],
#  'ant': ['ants'],
#  'antshar': ['antshare', 'antshares'],
#  'anybodi': ['anybody'],
#  'anylog': ['anylog'],
#  'anymor': ['anymore'],
#  'anyon': ['anyone'],
#  'anyth': ['anything'],
#  'anytim': ['anytime'],
#  'anyway': ['anyway', 'anyways'],
#  'anywher': ['anywhere'],
#  'apac': ['apac'],
#  'apex': ['apex'],
#  'aphelion': ['aphelion'],
#  'api': ['api', 'apis'],
#  'aplicacion': ['aplicaciones'],
#  'apollo': ['apollo'],
#  'apolog': ['apologies', 'apologize'],
#  'app': ['app', 'apps'],
#  'appar': ['apparent', 'apparently'],
#  'appeal': ['appeal', 'appealing'],
#  'appear': ['appear', 'appearance', 'appearances', 'appearing', 'appears'],
#  'appendix': ['appendix'],
#  'appetit': ['appetite'],
#  'appimag': ['appimage'],
#  'applaud': ['applaud'],
#  'appl': ['apple'],
#  'applic': ['applicable', 'applicants', 'application', 'applications'],
#  'appli': ['applied', 'applies', 'apply', 'applying'],
#  'appoint': ['appoints'],
#  'appreci': ['appreciate', 'appreciated', 'appreciates', 'appreciation'],
#  'approach': ['approach', 'approaches', 'approaching'],
#  'appropri': ['appropriate', 'appropriately', 'appropriating'],
#  'approv': ['approval', 'approved', 'approves'],
#  'approx': ['approx'],
#  'approxim': ['approximately'],
#  'apr': ['apr'],
#  'april': ['april'],
#  'ar': ['ar'],
#  'arab': ['arabic'],
#  'arbitrari': ['arbitrary'],
#  'arbitr': ['arbitrated'],
#  'architect': ['architect', 'architected'],
#  'architectur': ['architectural', 'architecture'],
#  'archiv': ['archives'],
#  'arco': ['arco'],
#  'area': ['area', 'areas'],
#  'arena': ['arena'],
#  'arenariu': ['arenarius'],
#  'arg': ['arg'],
#  'argentina': ['argentina'],
#  'argentinian': ['argentinian'],
#  'arguabl': ['arguably'],
#  'argu': ['argue', 'argues', 'arguing', 'argus'],
#  'argument': ['argument', 'arguments'],
#  'arigato': ['arigato'],
#  'aris': ['arising'],
#  'arithmet': ['arithmetic'],
#  'arizona': ['arizona'],
#  'ark': ['ark'],
#  'arkadiy': ['arkadiy'],
#  'arkansian': ['arkansians'],
#  'armi': ['armies', 'army'],
#  'armor': ['armored'],
#  'arm': ['arms'],
#  'armstrong': ['armstrong'],
#  'arnd': ['arnd'],
#  'aron': ['aron'],
#  'around': ['around'],
#  'arqit': ['arqit'],
#  'arrang': ['arrangement'],
#  'array': ['array'],
#  'arrest': ['arrested'],
#  'arriv': ['arrival', 'arrived', 'arrives', 'arriving'],
#  'art': ['art'],
#  'artamonov': ['artamonov'],
#  'artanomov': ['artanomov'],
#  'articl': ['article', 'articles'],
#  'artifici': ['artificial', 'artificially'],
#  'artist': ['artist', 'artists'],
#  'artmanov': ['artmanov'],
#  'artwork': ['artwork'],
#  'arvicco': ['arvicco'],
#  'asap': ['asap'],
#  'asar': ['asare'],
#  'ascend': ['ascended'],
#  'ascent': ['ascent'],
#  'ash': ['ashe'],
#  'ashley': ['ashley'],
#  'asia': ['asia'],
#  'asic': ['asic', 'asics'],
#  'asicboost': ['asicboost'],
#  'asid': ['aside'],
#  'ask': ['ask', 'asked', 'asking', 'asks'],
#  'asm': ['asm'],
#  'aso': ['asos'],
#  'aspect': ['aspect', 'aspects'],
#  'aspir': ['aspirations', 'aspiring'],
#  'assab': ['assab'],
#  'assassin': ['assassinations'],
#  'assc': ['assc'],
#  'assembl': ['assembled', 'assembly'],
#  'asset': ['asset', 'assets'],
#  'assett': ['assett'],
#  'assign': ['assignment'],
#  'assist': ['assist', 'assistance', 'assistant'],
#  'assistd': ['assistd'],
#  'assoc': ['assoc'],
#  'associ': ['associate', 'associated', 'association'],
#  'assum': ['assume', 'assuming'],
#  'assur': ['assurance', 'assure', 'assures', 'assuring'],
#  'astonish': ['astonishing'],
#  'astor': ['astor'],
#  'astound': ['astounding'],
#  'astrophys': ['astrophysics'],
#  'astroturf': ['astroturfers'],
#  'async': ['async'],
#  'asynchron': ['asynchronous', 'asynchronously'],
#  'ath': ['ath', 'aths'],
#  'athena': ['athena'],
#  'atlanta': ['atlanta'],
#  'atlanti': ['atlantis'],
#  'atl': ['atls'],
#  'atm': ['atm', 'atms'],
#  'atmospher': ['atmosphere'],
#  'atoken': ['atoken'],
#  'atom': ['atom', 'atomic', 'atoms'],
#  'atroci': ['atrocious'],
#  'attach': ['attached', 'attachment'],
#  'attack': ['attack',
#   'attacked',
#   'attacker',
#   'attackers',
#   'attacking',
#   'attacks'],
#  'attain': ['attains'],
#  'attempt': ['attempt', 'attempting', 'attempts'],
#  'attend': ['attend', 'attendance', 'attended', 'attending', 'attends'],
#  'attende': ['attendees'],
#  'attent': ['attention'],
#  'attitud': ['attitude'],
#  'attn': ['attn'],
#  'attorney': ['attorney'],
#  'attract': ['attract', 'attractive', 'attracts'],
#  'attribut': ['attribution'],
#  'attwat': ['attwater'],
#  'au': ['au'],
#  'aua': ['aua'],
#  'auckland': ['auckland'],
#  'auction': ['auction', 'auctions'],
#  'aud': ['aud'],
#  'audac': ['audacity'],
#  'audienc': ['audience', 'audiences'],
#  'audio': ['audio'],
#  'audit': ['audit',
#   'auditable',
#   'audited',
#   'auditing',
#   'audition',
#   'auditioning',
#   'audits'],
#  'auditor': ['auditor', 'auditors'],
#  'aug': ['aug'],
#  'auger': ['auger'],
#  'augment': ['augmented'],
#  'augur': ['augur', 'augurs'],
#  'augurnetwork': ['augurnetwork'],
#  'august': ['august'],
#  'aunction': ['aunctioned'],
#  'aussi': ['aussi'],
#  'austin': ['austin'],
#  'australia': ['australia'],
#  'australian': ['australian'],
#  'austria': ['austria'],
#  'austrian': ['austrian'],
#  'auth': ['auth'],
#  'authent': ['authenticated', 'authentication', 'authenticity'],
#  'author': ['author',
#   'authorities',
#   'authority',
#   'authorization',
#   'authorize',
#   'authorized'],
#  'authoritarian': ['authoritarians'],
#  'autoblock': ['autoblocked'],
#  'autom': ['automated', 'automating'],
#  'automat': ['automatic', 'automatically'],
#  'automobil': ['automobile'],
#  'autonom': ['autonomous'],
#  'avail': ['avail', 'availability', 'available'],
#  'avalanch': ['avalanche'],
#  'avatar': ['avatars'],
#  'avenu': ['avenues'],
#  'averag': ['average', 'averages'],
#  'avg': ['avg'],
#  'avigad': ['avigad'],
#  'aviv': ['aviv'],
#  'avoid': ['avoid', 'avoiding'],
#  'await': ['await', 'awaited', 'awaiting', 'awaits'],
#  'award': ['award', 'awarded', 'awards'],
#  'awar': ['aware', 'awareness'],
#  'away': ['away'],
#  'awemani': ['awemany'],
#  'awesom': ['awesome'],
#  'aw': ['awful', 'aws'],
#  'awhil': ['awhile'],
#  'ayahuasca': ['ayahuasca'],
#  'ayer': ['ayer'],
#  'ayr': ['ayr', 'ayre'],
#  'az': ['az'],
#  'azur': ['azure'],
#  'b': ['b'],
#  'baad': ['baad', 'baaaaad'],
#  'baa': ['baas'],
#  'babalola': ['babalola'],
#  'babbag': ['babbage'],
#  'babbitt': ['babbitt'],
#  'babi': ['babies', 'baby'],
#  'back': ['back', 'backed'],
#  'backbon': ['backbone'],
#  'backend': ['backend'],
#  'backer': ['backer'],
#  'backfe': ['backfeed'],
#  'backfir': ['backfired'],
#  'background': ['background', 'backgrounds'],
#  'backlash': ['backlash'],
#  'backlog': ['backlog', 'backlogged'],
#  'backpag': ['backpage'],
#  'backstag': ['backstage'],
#  'backup': ['backup', 'backups'],
#  'backward': ['backward'],
#  'bad': ['bad'],
#  'badg': ['badge', 'badges'],
#  'badli': ['badly'],
#  'baffl': ['baffled'],
#  'bag': ['bag', 'bags'],
#  'baidu': ['baidu'],
#  'bailout': ['bailout'],
#  'baimaohui': ['baimaohui'],
#  'bake': ['baked'],
#  'baker': ['baker'],
#  'bakon': ['bakon'],
#  'balanc': ['balance', 'balanced', 'balances'],
#  'bali': ['bali'],
#  'ballroom': ['ballroom'],
#  'ball': ['balls'],
#  'bamboozl': ['bamboozle'],
#  'ban': ['ban', 'banned'],
#  'bank': ['bank', 'banking', 'banks'],
#  'banker': ['banker'],
#  'banko': ['banko'],
#  'bankruptci': ['bankruptcy'],
#  'banner': ['banner'],
#  'banquet': ['banquet'],
#  'bar': ['bar'],
#  'barcelona': ['barcelona'],
#  'barclay': ['barclays'],
#  'bare': ['bare', 'barely'],
#  'barinov': ['barinov'],
#  'barrera': ['barrera'],
#  'barrier': ['barrier', 'barriers'],
#  'barri': ['barry'],
#  'base': ['base', 'based'],
#  'basezero': ['basezero'],
#  'bash': ['bash', 'bashing'],
#  'bashco': ['bashco'],
#  'basic': ['basic', 'basically', 'basics'],
#  'basi': ['basis'],
#  'batch': ['batch', 'batches'],
#  'batteri': ['battery'],
#  'battl': ['battle', 'battles'],
#  'bauerl': ['bauerle'],
#  'bay': ['bay'],
#  'bayer': ['bayer'],
#  'bazaar': ['bazaar'],
#  'bbc': ['bbc'],
#  'bbpingji': ['bbpingji'],
#  'bc': ['bc'],
#  'bcash': ['bcash'],
#  'bch': ['bch'],
#  'bcoin': ['bcoin'],
#  'bcrash': ['bcrash'],
#  'bd': ['bd'],
#  'bdn': ['bdn'],
#  'beach': ['beach'],
#  'beam': ['beam', 'beaming'],
#  'bear': ['bear', 'bears'],
#  'beat': ['beat', 'beats'],
#  'beau': ['beau'],
#  'beauregard': ['beauregard'],
#  'beauti': ['beautiful', 'beautifully'],
#  'becam': ['became'],
#  'beckman': ['beckmans'],
#  'becom': ['become', 'becomes', 'becoming'],
#  'becz': ['becze'],
#  'bedrock': ['bedrock'],
#  'beefi': ['beefy'],
#  'beer': ['beer'],
#  'beforehand': ['beforehand'],
#  'began': ['began'],
#  'beg': ['begging'],
#  'begin': ['begin', 'beginning', 'begins'],
#  'beginn': ['beginner', 'beginners'],
#  'begun': ['begun'],
#  'behalf': ['behalf'],
#  'behanc': ['behance'],
#  'behav': ['behave', 'behaving'],
#  'behavior': ['behavior', 'behavioral', 'behaviors'],
#  'behemoth': ['behemoth'],
#  'behind': ['behind'],
#  'behold': ['behold'],
#  'beij': ['beijing'],
#  'beijing': ['beijingers'],
#  'belan': ['belane'],
#  'belaru': ['belarus'],
#  'belat': ['belated'],
#  'belford': ['belford'],
#  'belief': ['belief', 'beliefs'],
#  'believ': ['believe', 'believer', 'believes', 'believing'],
#  'bell': ['bell'],
#  'belong': ['belong', 'belongs'],
#  'belt': ['belt'],
#  'benchmark': ['benchmark'],
#  'benefactor': ['benefactor'],
#  'benefit': ['benefit', 'benefits'],
#  'benjamin': ['benjamin'],
#  'benzinga': ['benzinga'],
#  'beosin': ['beosin'],
#  'berg': ['berg'],
#  'berkeley': ['berkeley'],
#  'berlin': ['berlin', 'berliners'],
#  'bernstein': ['bernstein'],
#  'bertoni': ['bertoni'],
#  'besid': ['besides'],
#  'besser': ['bessere'],
#  'best': ['best'],
#  'bet': ['bet', 'bets', 'betting'],
#  'beta': ['beta'],
#  'betsi': ['betsy'],
#  'better': ['better'],
#  'beverli': ['beverly'],
#  'bewar': ['beware'],
#  'beyond': ['beyond'],
#  'bft': ['bft'],
#  'bi': ['bi'],
#  'bianji': ['bianjie'],
#  'biannual': ['biannual'],
#  'bia': ['bias'],
#  'bias': ['biased'],
#  'bicycl': ['bicycle'],
#  'bid': ['bid', 'bidding'],
#  'bidirect': ['bidirectional'],
#  'big': ['big'],
#  'bigger': ['bigger'],
#  'biggest': ['biggest'],
#  'biggi': ['biggies'],
#  'bigqueri': ['bigquery'],
#  'bill': ['bill', 'billed', 'bills'],
#  'billboard': ['billboard'],
#  'billion': ['billion', 'billions'],
#  'billionair': ['billionaire'],
#  'billionth': ['billionth'],
#  'binanc': ['binance'],
#  'binari': ['binaries'],
#  'bind': ['binding', 'bindings'],
#  'bingo': ['bingo'],
#  'bio': ['bio', 'bios'],
#  'biotic': ['biotic'],
#  'bird': ['bird', 'birds'],
#  'birth': ['birth', 'birthed', 'birthing'],
#  'birthday': ['birthday'],
#  'birthplac': ['birthplace'],
#  'biswa': ['biswas'],
#  'bit': ['bit', 'bits'],
#  'bitangel': ['bitangels'],
#  'bitbeat': ['bitbeat'],
#  'bitbox': ['bitbox'],
#  'bitcard': ['bitcard'],
#  'bitclubnetwork': ['bitclubnetwork'],
#  'bitcoin': ['bitcoin', 'bitcoine', 'bitcoiners', 'bitcoins'],
#  'bitcoinabc': ['bitcoinabc'],
#  'bitcoincash': ['bitcoincash'],
#  'bitcoindecentr': ['bitcoindecentral'],
#  'bitcoinj': ['bitcoinj'],
#  'bitcointalk': ['bitcointalk'],
#  'bitcointravel': ['bitcointravel'],
#  'bitcoinxt': ['bitcoinxt'],
#  'bitconf': ['bitconf'],
#  'bitcorati': ['bitcorati'],
#  'bitek': ['bitek'],
#  'bitfinex': ['bitfinex'],
#  'bitflyer': ['bitflyer'],
#  'bitfuri': ['bitfury'],
#  'bithumb': ['bithumb'],
#  'bitkan': ['bitkan'],
#  'bitlicens': ['bitlicense'],
#  'bitmain': ['bitmain'],
#  'bitmex': ['bitmex'],
#  'bitoasi': ['bitoasis'],
#  'bitpanda': ['bitpanda'],
#  'bitpay': ['bitpay'],
#  'bitre': ['bitrees'],
#  'bitregistro': ['bitregistro'],
#  'bitshar': ['bitshares'],
#  'bitswap': ['bitswap'],
#  'bitter': ['bitter'],
#  'bittorr': ['bittorrent'],
#  'bittrex': ['bittrex'],
#  'bitti': ['bitty'],
#  'bitusd': ['bitusd'],
#  'bitvo': ['bitvo'],
#  'bitvot': ['bitvote'],
#  'bitwir': ['bitwires'],
#  'blacat': ['blacat'],
#  'black': ['black'],
#  'blacklist': ['blacklist', 'blacklisted'],
#  'blackmail': ['blackmail'],
#  'blame': ['blame'],
#  'blanket': ['blankets'],
#  'blast': ['blast', 'blasts'],
#  'blastoff': ['blastoff'],
#  'blatant': ['blatant'],
#  'bledel': ['bledel'],
#  'bleed': ['bleeding'],
#  'bletchley': ['bletchley'],
#  'bling': ['bling'],
#  'blink': ['blink'],
#  'blitzpredict': ['blitzpredict'],
#  'blkchain': ['blkchain'],
#  'blob': ['blobs'],
#  'block': ['block', 'blocked', 'blocking', 'blocks'],
#  'blockasset': ['blockasset'],
#  'blockchain': ['blockchain', 'blockchains'],
#  'blockdata': ['blockdata'],
#  'blocker': ['blockers'],
#  'blockfolio': ['blockfolio'],
#  'blockhain': ['blockhain'],
#  'blockhash': ['blockhash'],
#  'blockheight': ['blockheight'],
#  'blocklist': ['blocklist'],
#  'blockpress': ['blockpress'],
#  'blockscout': ['blockscout'],
#  'blocksiz': ['blocksize', 'blocksizes'],
#  'blocksplain': ['blocksplains'],
#  'blockstack': ['blockstack'],
#  'blockstream': ['blockstream'],
#  'blocktiv': ['blocktivity'],
#  'blog': ['blog', 'blogging', 'blogs'],
#  'blogger': ['blogger', 'bloggers'],
#  'blogpost': ['blogpost'],
#  'bloli': ['blolys'],
#  'blood': ['blood'],
#  'bloom': ['bloom'],
#  'bloomberg': ['bloomberg'],
#  'bloq': ['bloq'],
#  'blow': ['blow', 'blowing'],
#  'blucon': ['blucon'],
#  'blue': ['blue'],
#  'blueprint': ['blueprint'],
#  'board': ['board'],
#  'boardroom': ['boardroom'],
#  'boast': ['boasting', 'boasts'],
#  'boat': ['boats'],
#  'bob': ['bob', 'bobs'],
#  'bobesl': ['bobesled'],
#  'bobsl': ['bobsled'],
#  'bodog': ['bodog'],
#  'bodi': ['body'],
#  'bogatyrev': ['bogatyrev'],
#  'boil': ['boil'],
#  'boilerpl': ['boilerplate'],
#  'bois': ['boise'],
#  'bolchevshi': ['bolchevshy'],
#  'bollywood': ['bollywood'],
#  'bolster': ['bolster', 'bolstered', 'bolstering'],
#  'bolt': ['bolt'],
#  'bolychevski': ['bolychevsky'],
#  'bomb': ['bomb'],
#  'bond': ['bond', 'bonded', 'bonding', 'bonds'],
#  'bone': ['bones'],
#  'bontj': ['bontje'],
#  'bonu': ['bonus'],
#  'bonus': ['bonuses'],
#  'book': ['book', 'bookings', 'books'],
#  'bookmark': ['bookmark'],
#  'boom': ['boom', 'boomed', 'booming'],
#  'boost': ['boost', 'boosted', 'boosts'],
#  'boot': ['boot'],
#  'bootcamp': ['bootcamp'],
#  'booth': ['booth', 'booths'],
#  'bootstrap': ['bootstrap'],
#  'border': ['border', 'borders'],
#  'borderless': ['borderless'],
#  'borg': ['borg'],
#  'bore': ['boring'],
#  'born': ['born'],
#  'borrow': ['borrowed'],
#  'bo': ['bos'],
#  'bot': ['bot', 'bots'],
#  'botch': ['botched'],
#  'bother': ['bother'],
#  'botnet': ['botnets'],
#  'bottl': ['bottle'],
#  'bottleneck': ['bottlenecks'],
#  'bottom': ['bottom'],
#  'bought': ['bought'],
#  'boulder': ['boulder'],
#  'bound': ['bound', 'bounded'],
#  'boundari': ['boundaries'],
#  'bounti': ['bountied', 'bounties', 'bounty'],
#  'bowl': ['bowl'],
#  'box': ['box'],
#  'boy': ['boy', 'boys'],
#  'boycot': ['boycotting'],
#  'boyhood': ['boyhood'],
#  'bpo': ['bpos'],
#  'brad': ['brad'],
#  'brag': ['brag', 'bragging'],
#  'brain': ['brain', 'braine', 'brains'],
#  'brainstorm': ['brainstorming'],
#  'branch': ['branch', 'branches'],
#  'brand': ['brand', 'branding', 'brands'],
#  'branson': ['branson'],
#  'bratuskin': ['bratuskins'],
#  'brava': ['brava'],
#  'brazil': ['brazil'],
#  'brazilian': ['brazilian'],
#  'brd': ['brd'],
#  'breach': ['breaches'],
#  'bread': ['bread'],
#  'break': ['break', 'breaking', 'breaks'],
#  'breakaway': ['breakaway'],
#  'breakdown': ['breakdown'],
#  'breakneck': ['breakneck'],
#  'breakout': ['breakout'],
#  'breakthrough': ['breakthrough', 'breakthroughs'],
#  'breath': ['breath', 'breathe', 'breaths'],
#  'breather': ['breather'],
#  'breed': ['breed', 'breeds'],
#  'brett': ['brett'],
#  'brevicep': ['breviceps'],
#  'brew': ['brew', 'brewing'],
#  'breweri': ['brewery'],
#  'brian': ['brian'],
#  'bribabl': ['bribable'],
#  'bridg': ['bridge', 'bridges', 'bridging'],
#  'bridgett': ['bridgette'],
#  'brief': ['brief'],
#  'briefli': ['briefly'],
#  'brigad': ['brigaded', 'brigading'],
#  'bright': ['bright'],
#  'brighter': ['brighter'],
#  'brighton': ['brighton'],
#  'brilliant': ['brilliant'],
#  'bring': ['bring', 'bringing', 'brings'],
#  'brink': ['brink'],
#  'brisban': ['brisbane'],
#  'british': ['british'],
#  'bro': ['bro', 'bros'],
#  'broad': ['broad'],
#  'broadcast': ['broadcast', 'broadcasting'],
#  'broader': ['broader'],
#  'broken': ['broken'],
#  'brokerag': ['brokerage'],
#  'brook': ['brook', 'brooke'],
#  'brother': ['brothers'],
#  'brought': ['brought'],
#  'brownshirt': ['brownshirts'],
#  'brows': ['browse', 'browsing'],
#  'browser': ['browser', 'browsers'],
#  'bruh': ['bruh'],
#  'bruno': ['bruno'],
#  'brush': ['brush'],
#  'brussel': ['brussels'],
#  'bsl': ['bsl'],
#  'bst': ['bst'],
#  'btc': ['btc'],
#  'bter': ['bter'],
#  'btg': ['btg'],
#  'btrash': ['btrash'],
#  'btt': ['btt'],
#  'btw': ['btw'],
#  'bu': ['bu', 'bus'],
#  'bubbl': ['bubble'],
#  'bucash': ['bucash'],
#  'buchanan': ['buchanan'],
#  'bucharest': ['bucharest'],
#  'buchman': ['buchman'],
#  'bucket': ['bucket'],
#  'buckl': ['buckle'],
#  'budapest': ['budapest'],
#  'buffer': ['buffer'],
#  'buffet': ['buffet'],
#  'bug': ['bug', 'bugs'],
#  'bugfix': ['bugfix', 'bugfixes'],
#  'buidl': ['buidl'],
#  'build': ['build', 'building', 'buildings', 'builds'],
#  'buildboard': ['buildboard'],
#  'builder': ['builder', 'builders'],
#  'buildn': ['buildn'],
#  'built': ['built'],
#  'buitink': ['buitink'],
#  'bull': ['bull', 'bulls'],
#  'bullet': ['bullet'],
#  'bulletproof': ['bulletproof'],
#  'bullish': ['bullish', 'bullishness'],
#  'bullshit': ['bullshit'],
#  'bump': ['bump'],
#  'bumpi': ['bumpy'],
#  'bunch': ['bunch'],
#  'bungl': ['bungled'],
#  'bunk': ['bunk'],
#  'buntu': ['buntu'],
#  'burger': ['burgers'],
#  'burn': ['burning'],
#  'busiest': ['busiest'],
#  'busili': ['busily'],
#  'busi': ['business', 'businesses', 'busy'],
#  'buterin': ['buterin'],
#  'button': ['button', 'buttons'],
#  'buy': ['buy', 'buying', 'buys'],
#  'buyer': ['buyer', 'buyers'],
#  'buzzfe': ['buzzfeed'],
#  'buzz': ['buzzing'],
#  'buzzword': ['buzzword'],
#  'bylica': ['bylica'],
#  'bypass': ['bypassing'],
#  'byte': ['byte', 'bytes'],
#  'byzantin': ['byzantine'],
#  'byzantium': ['byzantium'],
#  'bzx': ['bzx'],
#  'c': ['c'],
#  'ca': ['ca'],
#  'cach': ['caching'],
#  'caf': ['caf'],
#  'cafe': ['cafe'],
#  'cafebar': ['cafebar'],
#  'cake': ['cake'],
#  'calcul': ['calculated',
#   'calculates',
#   'calculating',
#   'calculation',
#   'calculations',
#   'calculators'],
#  'calendar': ['calendar', 'calendars'],
#  'calgari': ['calgary'],
#  'california': ['california'],
#  'californian': ['californian'],
#  'call': ['call', 'called', 'calling', 'calls'],
#  'callback': ['callbacks'],
#  'calm': ['calm'],
#  'calvin': ['calvin'],
#  'cambridg': ['cambridge'],
#  'came': ['came'],
#  'camera': ['camera'],
#  'camp': ['camp'],
#  'campaign': ['campaign', 'campaigners'],
#  'campu': ['campus'],
#  'canaan': ['canaan'],
#  'canada': ['canada'],
#  'canadian': ['canadian'],
#  'canc': ['canc'],
#  'cancel': ['cancel', 'canceling'],
#  'cancun': ['cancun'],
#  'candid': ['candidate', 'candidates'],
#  'candlestick': ['candlestick'],
#  'candi': ['candy'],
#  'canesin': ['canesin'],
#  'canin': ['canines'],
#  'cant': ['cant'],
#  'cantones': ['cantonese'],
#  'canva': ['canvas'],
#  'cap': ['cap', 'capped', 'caps'],
#  'capabl': ['capabilities', 'capability', 'capable'],
#  'capac': ['capacity'],
#  'capit': ['capital', 'capitalism'],
#  'capitalist': ['capitalist'],
#  'capt': ['capt'],
#  'captiv': ['captivating'],
#  'captur': ['capture', 'captured', 'capturing'],
#  'car': ['car', 'cars'],
#  'caraca': ['caracas'],
#  'carblock': ['carblock'],
#  'card': ['card', 'cards'],
#  'cardano': ['cardano'],
#  'cardmak': ['cardmaker'],
#  'care': ['care', 'careful', 'carefully', 'cares', 'caring'],
#  'career': ['career', 'careers'],
#  'caribbean': ['caribbean'],
#  'carl': ['carl'],
#  'carri': ['carried', 'carries', 'carry', 'carrying'],
#  'carsten': ['carsten'],
#  'cartel': ['cartel'],
#  'cartoon': ['cartoon'],
#  'cascad': ['cascaded'],
#  'case': ['case', 'cases'],
#  'casey': ['casey'],
#  'cash': ['cash'],
#  'cashaddr': ['cashaddr'],
#  'cashback': ['cashback'],
#  'cashshuffl': ['cashshuffle'],
#  'casino': ['casino'],
#  'casper': ['casper'],
#  'cast': ['cast'],
#  'castl': ['castle'],
#  'casual': ['casual'],
#  'cat': ['cat', 'cats'],
#  'catch': ['catch', 'catching'],
#  'cate': ['cate'],
#  'categor': ['categorical', 'categorizations'],
#  'categori': ['categories', 'category'],
#  'cater': ['cater', 'catered'],
#  'cathod': ['cathode'],
#  'caught': ['caught'],
#  'caus': ['cause', 'caused', 'causing'],
#  'caution': ['caution'],
#  'cave': ['cave'],
#  'caveat': ['caveats'],
#  'cb': ['cb'],
#  'cbr': ['cbr'],
#  'cc': ['cc'],
#  'ccid': ['ccid'],
#  'ccidn': ['ccidn'],
#  'ccm': ['ccm'],
#  'ccss': ['ccss'],
#  'ccx': ['ccx'],
#  'cdn': ['cdn'],
#  'ce': ['ce', 'ces'],
#  'cebe': ['cebe'],
#  'ceil': ['ceiling'],
#  'celebr': ['celebrate',
#   'celebrated',
#   'celebrates',
#   'celebrating',
#   'celebration'],
#  'cell': ['cell', 'cells'],
#  'censor': ['censor', 'censored', 'censoring'],
#  'censorship': ['censorship'],
#  'cent': ['cent', 'cents'],
#  'center': ['center', 'centered', 'centers'],
#  'central': ['central',
#   'centralization',
#   'centralized',
#   'centralizing',
#   'centrally'],
#  'centr': ['centre'],
#  'centric': ['centric'],
#  'centuri': ['centuries'],
#  'ceo': ['ceo'],
#  'ceremoni': ['ceremony'],
#  'certain': ['certain'],
#  'certainli': ['certainly'],
#  'certif': ['certificate', 'certificates'],
#  'certik': ['certik'],
#  'cet': ['cet'],
#  'cew': ['cew'],
#  'cex': ['cex'],
#  'cfca': ['cfca'],
#  'cftc': ['cftc'],
#  'cga': ['cgas'],
#  'ch': ['ch'],
#  'chadha': ['chadha'],
#  'chain': ['chain', 'chains'],
#  'chainalysi': ['chainalysis'],
#  'chainbet': ['chainbet'],
#  'chainday': ['chainday'],
#  'chainer': ['chainers'],
#  'chainhop': ['chainhop', 'chainhopping', 'chainhops'],
#  'chainid': ['chainid'],
#  ...}

# %%
print(len(bag_of_words_dict_2))
# Out:
# 6950

# %%
def save_dict_to_file(diction,path):
    f = open(path + 'Zhiyuan_Li_word_dict_after_stemming.csv','w+')
    for key,value in diction.items():
        line = ','.join(str(x) for x in value)
        f.write(key + ':' + line + '\n')
    f.close()
    return None

# %%
save_dict_to_file(diction=bag_of_words_dict_2,path=path)

# %%
path
# Out:
# '/mnt/c/Users/Administrator.DESKTOP-OHBO1TS/Desktop/Prof_Eesley/github/'
